# %%
import glob
from pathlib import Path

# %% [markdown]
# # DATASET

# %%
classes_dir = glob.glob("/kaggle/input/plantvillage dataset/color/*")

len(classes_dir)
# Out:
# 38

# %%
images = glob.glob('/kaggle/input/plantvillage dataset/color/**/**')
len(images)
# Out:
# 54305

# %%
for class_dir in classes_dir:
    class_dir_path = Path(class_dir)
    class_name = class_dir_path.name
    class_images = glob.glob(f'{class_dir}/*')
    print(f'{class_name:<55}: {len(class_images)}')
# Out:
# Tomato___Late_blight                                   : 1909
# Tomato___healthy                                       : 1591
# Grape___healthy                                        : 423
# Orange___Haunglongbing_(Citrus_greening)               : 5507
# Soybean___healthy                                      : 5090
# Squash___Powdery_mildew                                : 1835
# Potato___healthy                                       : 152
# Corn_(maize)___Northern_Leaf_Blight                    : 985
# Tomato___Early_blight                                  : 1000
# Tomato___Septoria_leaf_spot                            : 1771
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot     : 513
# Strawberry___Leaf_scorch                               : 1109
# Peach___healthy                                        : 360
# Apple___Apple_scab                                     : 630
# Tomato___Tomato_Yellow_Leaf_Curl_Virus                 : 5357
# Tomato___Bacterial_spot                                : 2127
# Apple___Black_rot                                      : 621
# Blueberry___healthy                                    : 1502
# Cherry_(including_sour)___Powdery_mildew               : 1052
# Peach___Bacterial_spot                                 : 2297
# Apple___Cedar_apple_rust                               : 275
# Tomato___Target_Spot                                   : 1404
# Pepper,_bell___healthy                                 : 1478
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)             : 1076
# Potato___Late_blight                                   : 1000
# Tomato___Tomato_mosaic_virus                           : 373
# Strawberry___healthy                                   : 456
# Apple___healthy                                        : 1645
# Grape___Black_rot                                      : 1180
# Potato___Early_blight                                  : 1000
# Cherry_(including_sour)___healthy                      : 854
# Corn_(maize)___Common_rust_                            : 1192
# Grape___Esca_(Black_Measles)                           : 1383
# Raspberry___healthy                                    : 371
# Tomato___Leaf_Mold                                     : 952
# Tomato___Spider_mites Two-spotted_spider_mite          : 1676
# Pepper,_bell___Bacterial_spot                          : 997
# Corn_(maize)___healthy                                 : 1162

# %%
import tensorflow as tf
import random
import cv2
import skimage

import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2024-06-27 15:34:11.101701: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-27 15:34:11.101824: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-27 15:34:11.267846: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
class PlantVillageGenerator:
    def __init__(self, files_path, labels_to_idx, image_size, shuffle=True, color_space='rgb', split_channel=None, one_channel=None):
        self.files_path = files_path
        self.labels_to_idx = labels_to_idx
        self.image_size = image_size
        self.shuffle = shuffle
        self.color_space = color_space
        self.split_channel = split_channel
        self.one_channel = one_channel
    
    def __call__(self):
        if self.shuffle:
            random.shuffle(self.files_path)
        
        for file_path in self.files_path:
            label_str = Path(file_path).parent.name
            label_idx = self.labels_to_idx[label_str]
            label_oh = tf.one_hot(label_idx, len(self.labels_to_idx))

            image = tf.keras.preprocessing.image.load_img(file_path)
            image_arr = tf.keras.preprocessing.image.img_to_array(image)
            image_arr = tf.image.resize_with_pad(image_arr, self.image_size[0], self.image_size[1])
            image_arr /= 255.

            if self.color_space == 'lab':
                image_arr = tf.py_function(func=skimage.color.rgb2lab, inp=[image_arr], Tout=tf.float32)
                image_arr = (image_arr + [0, 128, 128]) / [100, 255, 255]
                image_arr.set_shape((*self.image_size, 3))
            elif self.color_space != 'rgb':
                raise NotImplementedError

            if self.split_channel:
                first_channel = tf.reshape(image_arr[:, :, 0], (*self.image_size, 1))
                second_channel = tf.reshape(image_arr[:, :, 1], (*self.image_size, 1))
                third_channel = tf.reshape(image_arr[:, :, 2], (*self.image_size, 1))
                
                concat = tf.concat([second_channel, third_channel], 2)

                yield (first_channel, concat), label_oh
            elif self.one_channel and self.one_channel == "AB":
                ab_channel = tf.reshape(image_arr[:, :, 1:], (*self.image_size, 2))

                yield ab_channel, label_oh
            elif self.one_channel and self.one_channel == "L":
                l_channel = tf.reshape(image_arr[:, :, 0], (*self.image_size, 1))
                yield l_channel, label_oh
            else:
                yield image_arr, label_oh

# %%
from collections import defaultdict
import copy
import random
from pathlib import Path

def train_validation_test_split(files_path, train_size=0.7, validation_size=0.2):
    files_path = copy.deepcopy(files_path)
    random.shuffle(files_path)
    
    files_per_class = defaultdict(list)
    for f in files_path:
        label = Path(f).parent.name
        files_per_class[label].append(f)
    
    split_files = defaultdict(list)
    for c, files in files_per_class.items():
        train_count = int(len(files) * train_size)
        validation_count = int(len(files) * validation_size)
        
        split_files['train'] += (files[:train_count])
        split_files['validation'] += (files[train_count:(train_count+validation_count)])
        split_files['test'] += (files[(train_count+validation_count):])
    
    return split_files

# %%
files_path = glob.glob('/kaggle/input/plantvillage dataset/color/**/**')
split_files = train_validation_test_split(files_path)
classes = set([Path(f).parent.name for f in files_path])
labels_to_idx = {c: i for i, c in enumerate(classes)}

output_signature = ((tf.TensorSpec(shape = (None, None, 1), dtype = tf.float32), tf.TensorSpec(shape = (None, None, 2), dtype = tf.float32)),
                    tf.TensorSpec(shape = (len(labels_to_idx)), dtype = tf.int16))

train = tf.data.Dataset.from_generator(
    PlantVillageGenerator(split_files['train'], labels_to_idx, (128, 128), color_space='lab', split_channel=True),
    output_signature=output_signature
)
validation = tf.data.Dataset.from_generator(
    PlantVillageGenerator(split_files['validation'], labels_to_idx, (128, 128), color_space='lab', split_channel=True),
    output_signature=output_signature
)
test = tf.data.Dataset.from_generator(
    PlantVillageGenerator(split_files['test'], labels_to_idx, (128, 128), color_space='lab', split_channel=True),
    output_signature=output_signature
)

# %%
img,label = next(iter(test))
print(img[0].shape)
print(img[1].shape)
print(label.shape)
# Out:
# (128, 128, 1)
# (128, 128, 2)
# (38,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train = train.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)
validation = validation.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)
test = test.shuffle(1000).prefetch(buffer_size = AUTOTUNE)

# %%
batched_train = train.batch(32)
batched_validation = validation.batch(32)
batched_test = test.batch(32)

# %% [markdown]
# # MODEL

# %%
DEFAULT_BLOCKS_ARGS = {
    "efficientnetv2-s": [
        {
            "kernel_size": 3,
            "num_repeat": 2,
            "input_filters": 24,
            "output_filters": 24,
            "expand_ratio": 1,
            "se_ratio": 0.0,
            "strides": 1,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 4,
            "input_filters": 24,
            "output_filters": 48,
            "expand_ratio": 4,
            "se_ratio": 0.0,
            "strides": 2,
            "conv_type": 1,
        },
        {
            "conv_type": 1,
            "expand_ratio": 4,
            "input_filters": 48,
            "kernel_size": 3,
            "num_repeat": 4,
            "output_filters": 64,
            "se_ratio": 0,
            "strides": 2,
        },
        {
            "conv_type": 0,
            "expand_ratio": 4,
            "input_filters": 64,
            "kernel_size": 3,
            "num_repeat": 6,
            "output_filters": 128,
            "se_ratio": 0.25,
            "strides": 2,
        },
        {
            "conv_type": 0,
            "expand_ratio": 6,
            "input_filters": 128,
            "kernel_size": 3,
            "num_repeat": 9,
            "output_filters": 160,
            "se_ratio": 0.25,
            "strides": 1,
        },
        {
            "conv_type": 0,
            "expand_ratio": 6,
            "input_filters": 160,
            "kernel_size": 3,
            "num_repeat": 15,
            "output_filters": 256,
            "se_ratio": 0.25,
            "strides": 2,
        },
    ],
    "efficientnetv2-m": [
        {
            "kernel_size": 3,
            "num_repeat": 3,
            "input_filters": 24,
            "output_filters": 24,
            "expand_ratio": 1,
            "se_ratio": 0,
            "strides": 1,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 5,
            "input_filters": 24,
            "output_filters": 48,
            "expand_ratio": 4,
            "se_ratio": 0,
            "strides": 2,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 5,
            "input_filters": 48,
            "output_filters": 80,
            "expand_ratio": 4,
            "se_ratio": 0,
            "strides": 2,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 7,
            "input_filters": 80,
            "output_filters": 160,
            "expand_ratio": 4,
            "se_ratio": 0.25,
            "strides": 2,
            "conv_type": 0,
        },
        {
            "kernel_size": 3,
            "num_repeat": 14,
            "input_filters": 160,
            "output_filters": 176,
            "expand_ratio": 6,
            "se_ratio": 0.25,
            "strides": 1,
            "conv_type": 0,
        },
        {
            "kernel_size": 3,
            "num_repeat": 18,
            "input_filters": 176,
            "output_filters": 304,
            "expand_ratio": 6,
            "se_ratio": 0.25,
            "strides": 2,
            "conv_type": 0,
        },
        {
            "kernel_size": 3,
            "num_repeat": 5,
            "input_filters": 304,
            "output_filters": 512,
            "expand_ratio": 6,
            "se_ratio": 0.25,
            "strides": 1,
            "conv_type": 0,
        },
    ],
    "efficientnetv2-l": [
        {
            "kernel_size": 3,
            "num_repeat": 4,
            "input_filters": 32,
            "output_filters": 32,
            "expand_ratio": 1,
            "se_ratio": 0,
            "strides": 1,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 7,
            "input_filters": 32,
            "output_filters": 64,
            "expand_ratio": 4,
            "se_ratio": 0,
            "strides": 2,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 7,
            "input_filters": 64,
            "output_filters": 96,
            "expand_ratio": 4,
            "se_ratio": 0,
            "strides": 2,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 10,
            "input_filters": 96,
            "output_filters": 192,
            "expand_ratio": 4,
            "se_ratio": 0.25,
            "strides": 2,
            "conv_type": 0,
        },
        {
            "kernel_size": 3,
            "num_repeat": 19,
            "input_filters": 192,
            "output_filters": 224,
            "expand_ratio": 6,
            "se_ratio": 0.25,
            "strides": 1,
            "conv_type": 0,
        },
        {
            "kernel_size": 3,
            "num_repeat": 25,
            "input_filters": 224,
            "output_filters": 384,
            "expand_ratio": 6,
            "se_ratio": 0.25,
            "strides": 2,
            "conv_type": 0,
        },
        {
            "kernel_size": 3,
            "num_repeat": 7,
            "input_filters": 384,
            "output_filters": 640,
            "expand_ratio": 6,
            "se_ratio": 0.25,
            "strides": 1,
            "conv_type": 0,
        },
    ],
    "efficientnetv2-b0": [
        {
            "kernel_size": 3,
            "num_repeat": 1,
            "input_filters": 32,
            "output_filters": 16,
            "expand_ratio": 1,
            "se_ratio": 0,
            "strides": 1,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 2,
            "input_filters": 16,
            "output_filters": 32,
            "expand_ratio": 4,
            "se_ratio": 0,
            "strides": 2,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 2,
            "input_filters": 32,
            "output_filters": 48,
            "expand_ratio": 4,
            "se_ratio": 0,
            "strides": 2,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 3,
            "input_filters": 48,
            "output_filters": 96,
            "expand_ratio": 4,
            "se_ratio": 0.25,
            "strides": 2,
            "conv_type": 0,
        },
        {
            "kernel_size": 3,
            "num_repeat": 5,
            "input_filters": 96,
            "output_filters": 112,
            "expand_ratio": 6,
            "se_ratio": 0.25,
            "strides": 1,
            "conv_type": 0,
        },
        {
            "kernel_size": 3,
            "num_repeat": 8,
            "input_filters": 112,
            "output_filters": 192,
            "expand_ratio": 6,
            "se_ratio": 0.25,
            "strides": 2,
            "conv_type": 0,
        },
    ],
    "efficientnetv2-b1": [
        {
            "kernel_size": 3,
            "num_repeat": 1,
            "input_filters": 32,
            "output_filters": 16,
            "expand_ratio": 1,
            "se_ratio": 0,
            "strides": 1,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 2,
            "input_filters": 16,
            "output_filters": 32,
            "expand_ratio": 4,
            "se_ratio": 0,
            "strides": 2,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 2,
            "input_filters": 32,
            "output_filters": 48,
            "expand_ratio": 4,
            "se_ratio": 0,
            "strides": 2,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 3,
            "input_filters": 48,
            "output_filters": 96,
            "expand_ratio": 4,
            "se_ratio": 0.25,
            "strides": 2,
            "conv_type": 0,
        },
        {
            "kernel_size": 3,
            "num_repeat": 5,
            "input_filters": 96,
            "output_filters": 112,
            "expand_ratio": 6,
            "se_ratio": 0.25,
            "strides": 1,
            "conv_type": 0,
        },
        {
            "kernel_size": 3,
            "num_repeat": 8,
            "input_filters": 112,
            "output_filters": 192,
            "expand_ratio": 6,
            "se_ratio": 0.25,
            "strides": 2,
            "conv_type": 0,
        },
    ],
    "efficientnetv2-b2": [
        {
            "kernel_size": 3,
            "num_repeat": 1,
            "input_filters": 32,
            "output_filters": 16,
            "expand_ratio": 1,
            "se_ratio": 0,
            "strides": 1,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 2,
            "input_filters": 16,
            "output_filters": 32,
            "expand_ratio": 4,
            "se_ratio": 0,
            "strides": 2,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 2,
            "input_filters": 32,
            "output_filters": 48,
            "expand_ratio": 4,
            "se_ratio": 0,
            "strides": 2,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 3,
            "input_filters": 48,
            "output_filters": 96,
            "expand_ratio": 4,
            "se_ratio": 0.25,
            "strides": 2,
            "conv_type": 0,
        },
        {
            "kernel_size": 3,
            "num_repeat": 5,
            "input_filters": 96,
            "output_filters": 112,
            "expand_ratio": 6,
            "se_ratio": 0.25,
            "strides": 1,
            "conv_type": 0,
        },
        {
            "kernel_size": 3,
            "num_repeat": 8,
            "input_filters": 112,
            "output_filters": 192,
            "expand_ratio": 6,
            "se_ratio": 0.25,
            "strides": 2,
            "conv_type": 0,
        },
    ],
    "efficientnetv2-b3": [
        {
            "kernel_size": 3,
            "num_repeat": 1,
            "input_filters": 32,
            "output_filters": 16,
            "expand_ratio": 1,
            "se_ratio": 0,
            "strides": 1,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 2,
            "input_filters": 16,
            "output_filters": 32,
            "expand_ratio": 4,
            "se_ratio": 0,
            "strides": 2,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 2,
            "input_filters": 32,
            "output_filters": 48,
            "expand_ratio": 4,
            "se_ratio": 0,
            "strides": 2,
            "conv_type": 1,
        },
        {
            "kernel_size": 3,
            "num_repeat": 3,
            "input_filters": 48,
            "output_filters": 96,
            "expand_ratio": 4,
            "se_ratio": 0.25,
            "strides": 2,
            "conv_type": 0,
        },
        {
            "kernel_size": 3,
            "num_repeat": 5,
            "input_filters": 96,
            "output_filters": 112,
            "expand_ratio": 6,
            "se_ratio": 0.25,
            "strides": 1,
            "conv_type": 0,
        },
        {
            "kernel_size": 3,
            "num_repeat": 8,
            "input_filters": 112,
            "output_filters": 192,
            "expand_ratio": 6,
            "se_ratio": 0.25,
            "strides": 2,
            "conv_type": 0,
        },
    ],
}

CONV_KERNEL_INITIALIZER = {
    "class_name": "VarianceScaling",
    "config": {
        "scale": 2.0,
        "mode": "fan_out",
        "distribution": "truncated_normal",
    },
}

DENSE_KERNEL_INITIALIZER = {
    "class_name": "VarianceScaling",
    "config": {
        "scale": 1.0 / 3.0,
        "mode": "fan_out",
        "distribution": "uniform",
    },
}

# %%
import math

def round_filters(filters, width_coefficient, min_depth, depth_divisor):
    """Round number of filters based on depth multiplier."""
    filters *= width_coefficient
    minimum_depth = min_depth or depth_divisor
    new_filters = max(
        minimum_depth,
        int(filters + depth_divisor / 2) // depth_divisor * depth_divisor,
    )
    return int(new_filters)


def round_repeats(repeats, depth_coefficient):
    """Round number of repeats based on depth multiplier."""
    return int(math.ceil(depth_coefficient * repeats))

# %%
import copy

from keras.src import backend
from keras.src import initializers
from keras.src import layers
from keras.src.api_export import keras_export
from keras.src.models import Functional

# %%
def FusedMBConvBlock(
    input_filters,
    output_filters,
    expand_ratio=1,
    kernel_size=3,
    strides=1,
    se_ratio=0.0,
    bn_momentum=0.9,
    activation="swish",
    survival_probability=0.8,
    name=None,
):
    """Fuses the proj conv1x1 and depthwise_conv into a conv2d."""
    bn_axis = 3 if backend.image_data_format() == "channels_last" else 1

    if name is None:
        name = backend.get_uid("block0")

    def apply(inputs):
        filters = input_filters * expand_ratio
        if expand_ratio != 1:
            x = layers.Conv2D(
                filters,
                kernel_size=kernel_size,
                strides=strides,
                kernel_initializer=CONV_KERNEL_INITIALIZER,
                data_format=backend.image_data_format(),
                padding="same",
                use_bias=False,
                name=name + "expand_conv",
            )(inputs)
            x = layers.BatchNormalization(
                axis=bn_axis, momentum=bn_momentum, name=name + "expand_bn"
            )(x)
            x = layers.Activation(
                activation=activation, name=name + "expand_activation"
            )(x)
        else:
            x = inputs

        # Squeeze and excite
        if 0 < se_ratio <= 1:
            filters_se = max(1, int(input_filters * se_ratio))
            se = layers.GlobalAveragePooling2D(name=name + "se_squeeze")(x)
            if bn_axis == 1:
                se_shape = (filters, 1, 1)
            else:
                se_shape = (1, 1, filters)

            se = layers.Reshape(se_shape, name=name + "se_reshape")(se)

            se = layers.Conv2D(
                filters_se,
                1,
                padding="same",
                activation=activation,
                kernel_initializer=CONV_KERNEL_INITIALIZER,
                name=name + "se_reduce",
            )(se)
            se = layers.Conv2D(
                filters,
                1,
                padding="same",
                activation="sigmoid",
                kernel_initializer=CONV_KERNEL_INITIALIZER,
                name=name + "se_expand",
            )(se)

            x = layers.multiply([x, se], name=name + "se_excite")

        # Output phase:
        x = layers.Conv2D(
            output_filters,
            kernel_size=1 if expand_ratio != 1 else kernel_size,
            strides=1 if expand_ratio != 1 else strides,
            kernel_initializer=CONV_KERNEL_INITIALIZER,
            padding="same",
            use_bias=False,
            name=name + "project_conv",
        )(x)
        x = layers.BatchNormalization(
            axis=bn_axis, momentum=bn_momentum, name=name + "project_bn"
        )(x)
        if expand_ratio == 1:
            x = layers.Activation(
                activation=activation, name=name + "project_activation"
            )(x)

        # Residual:
        if strides == 1 and input_filters == output_filters:
            if survival_probability:
                x = layers.Dropout(
                    survival_probability,
                    noise_shape=(None, 1, 1, 1),
                    name=name + "drop",
                )(x)
            x = layers.add([x, inputs], name=name + "add")
        return x

    return apply

# %%
def MBConvBlock(
    input_filters,
    output_filters,
    expand_ratio=1,
    kernel_size=3,
    strides=1,
    se_ratio=0.0,
    bn_momentum=0.9,
    activation="swish",
    survival_probability=0.8,
    name=None,
):
    """MBConv block: Mobile Inverted Residual Bottleneck."""
    bn_axis = 3 if backend.image_data_format() == "channels_last" else 1

    if name is None:
        name = backend.get_uid("block0")

    def apply(inputs):
        # Expansion phase
        filters = input_filters * expand_ratio
        if expand_ratio != 1:
            x = layers.Conv2D(
                filters=filters,
                kernel_size=1,
                strides=1,
                kernel_initializer=CONV_KERNEL_INITIALIZER,
                padding="same",
                data_format=backend.image_data_format(),
                use_bias=False,
                name=name + "expand_conv",
            )(inputs)
            x = layers.BatchNormalization(
                axis=bn_axis,
                momentum=bn_momentum,
                name=name + "expand_bn",
            )(x)
            x = layers.Activation(activation, name=name + "expand_activation")(
                x
            )
        else:
            x = inputs

        # Depthwise conv
        x = layers.DepthwiseConv2D(
            kernel_size=kernel_size,
            strides=strides,
            depthwise_initializer=CONV_KERNEL_INITIALIZER,
            padding="same",
            data_format=backend.image_data_format(),
            use_bias=False,
            name=name + "dwconv2",
        )(x)
        x = layers.BatchNormalization(
            axis=bn_axis, momentum=bn_momentum, name=name + "bn"
        )(x)
        x = layers.Activation(activation, name=name + "activation")(x)

        # Squeeze and excite
        if 0 < se_ratio <= 1:
            filters_se = max(1, int(input_filters * se_ratio))
            se = layers.GlobalAveragePooling2D(name=name + "se_squeeze")(x)
            if bn_axis == 1:
                se_shape = (filters, 1, 1)
            else:
                se_shape = (1, 1, filters)
            se = layers.Reshape(se_shape, name=name + "se_reshape")(se)

            se = layers.Conv2D(
                filters_se,
                1,
                padding="same",
                activation=activation,
                kernel_initializer=CONV_KERNEL_INITIALIZER,
                name=name + "se_reduce",
            )(se)
            se = layers.Conv2D(
                filters,
                1,
                padding="same",
                activation="sigmoid",
                kernel_initializer=CONV_KERNEL_INITIALIZER,
                name=name + "se_expand",
            )(se)

            x = layers.multiply([x, se], name=name + "se_excite")

        # Output phase
        x = layers.Conv2D(
            filters=output_filters,
            kernel_size=1,
            strides=1,
            kernel_initializer=CONV_KERNEL_INITIALIZER,
            padding="same",
            data_format=backend.image_data_format(),
            use_bias=False,
            name=name + "project_conv",
        )(x)
        x = layers.BatchNormalization(
            axis=bn_axis, momentum=bn_momentum, name=name + "project_bn"
        )(x)

        if strides == 1 and input_filters == output_filters:
            if survival_probability:
                x = layers.Dropout(
                    survival_probability,
                    noise_shape=(None, 1, 1, 1),
                    name=name + "drop",
                )(x)
            x = layers.add([x, inputs], name=name + "add")

        return x

    return apply

# %%
def EfficientNetV2(
    width_coefficient,
    depth_coefficient,
    default_size,
    dropout_rate=0.2,
    drop_connect_rate=0.2,
    depth_divisor=8,
    min_depth=8,
    bn_momentum=0.9,
    activation="swish",
    blocks_args="default",
    model_name="efficientnetv2",
    include_top=True,
    l_input_shape=None,
    ab_input_shape=None,
    l_ratio=0.5,
    num_blocks_to_branch=3,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
    include_preprocessing=True,
    branch_stem=True,
    input_shape=None,
):
    """Instantiates the EfficientNetV2 architecture using given scaling
    coefficients.

    Args:
        width_coefficient: float, scaling coefficient for network width.
        depth_coefficient: float, scaling coefficient for network depth.
        default_size: integer, default input image size.
        dropout_rate: float, dropout rate before final classifier layer.
        drop_connect_rate: float, dropout rate at skip connections.
        depth_divisor: integer, a unit of network width.
        min_depth: integer, minimum number of filters.
        bn_momentum: float. Momentum parameter for Batch Normalization layers.
        activation: activation function.
        blocks_args: list of dicts, parameters to construct block modules.
        model_name: string, model name.
        include_top: whether to include the fully-connected layer at the top of
            the network.
        weights: one of None (random initialization), "imagenet"
            (pre-training on ImageNet),
            or the path to the weights file to be loaded.
        input_tensor: optional Keras tensor (i.e. output of `layers.Input()`) or
            numpy array to use as image input for the model.
        input_shape: optional shape tuple, only to be specified if include_top
            is `False`. It should have exactly 3 inputs channels.
        pooling: optional pooling mode for feature extraction when include_top
            is `False`.
            - None means that the output of the model will be the
                4D tensor output of the last convolutional layer.
            - "avg" means that global average pooling will be applied to
                the output of the last convolutional layer,
                and thus the output of the model will be a 2D tensor.
            - "max" means that global max pooling will be applied.
        classes: optional number of classes to classify images into,
            only to be specified if include_top is `True`, and if no weights
            argument is specified.
        classifier_activation: A string or callable. The activation function to
            use on the "top" layer. Ignored unless `include_top=True`. Set
            classifier_activation=None to return the logits of the "top"
            layer.
        include_preprocessing: Boolean, whether to include the preprocessing
            layer (`Rescaling`) at the bottom of the network.
            Defaults to `True`.

    Returns:
        A model instance.
    """

    if blocks_args == "default":
        blocks_args = DEFAULT_BLOCKS_ARGS[model_name]
        
    
    if branch_stem:
        l_inputs = layers.Input(shape=l_input_shape)
        ab_inputs = layers.Input(shape=ab_input_shape)

        bn_axis = 3 if backend.image_data_format() == "channels_last" else 1

        x_l = l_inputs
        x_ab = ab_inputs

        # Build stem
        stem_filters = round_filters(
            filters=blocks_args[0]["input_filters"],
            width_coefficient=width_coefficient,
            min_depth=min_depth,
            depth_divisor=depth_divisor,
        )
        l_filters = int(stem_filters * l_ratio)
        ab_filters = stem_filters - l_filters
        # l stem
        x_l = layers.Conv2D(
            filters=l_filters,
            kernel_size=3,
            strides=2,
            kernel_initializer=CONV_KERNEL_INITIALIZER,
            padding="same",
            use_bias=False,
            name="l_stem_conv",
        )(x_l)
        x_l = layers.BatchNormalization(
            axis=bn_axis,
            momentum=bn_momentum,
            name="l_stem_bn",
        )(x_l)
        x_l = layers.Activation(activation, name="l_stem_activation")(x_l)

        # ab stem
        x_ab = layers.Conv2D(
            filters=ab_filters,
            kernel_size=3,
            strides=2,
            kernel_initializer=CONV_KERNEL_INITIALIZER,
            padding="same",
            use_bias=False,
            name="ab_stem_conv",
        )(x_ab)
        x_ab = layers.BatchNormalization(
            axis=bn_axis,
            momentum=bn_momentum,
            name="ab_stem_bn",
        )(x_ab)
        x_ab = layers.Activation(activation, name="ab_stem_activation")(x_ab)
    else:
        inputs = layers.Input(shape=input_shape)
        bn_axis = 3 if backend.image_data_format() == "channels_last" else 1
        
        stem_filters = round_filters(
            filters=blocks_args[0]["input_filters"],
            width_coefficient=width_coefficient,
            min_depth=min_depth,
            depth_divisor=depth_divisor,
        )
        
        x = layers.Conv2D(
            filters=stem_filters,
            kernel_size=3,
            strides=2,
            kernel_initializer=CONV_KERNEL_INITIALIZER,
            padding="same",
            use_bias=False,
            name="l_stem_conv",
        )(inputs)
        x = layers.BatchNormalization(
            axis=bn_axis,
            momentum=bn_momentum,
            name="l_stem_bn",
        )(x)
        x = layers.Activation(activation, name="l_stem_activation")(x)

    blocks_args = copy.deepcopy(blocks_args)
    b = 0
    blocks = float(sum(args["num_repeat"] for args in blocks_args))
    
    blocks_args_with_name = []
    for i, block_args in enumerate(blocks_args):
        block_args["input_filters"] = round_filters(
            filters=block_args["input_filters"],
            width_coefficient=width_coefficient,
            min_depth=min_depth,
            depth_divisor=depth_divisor,
        )
        block_args["output_filters"] = round_filters(
            filters=block_args["output_filters"],
            width_coefficient=width_coefficient,
            min_depth=min_depth,
            depth_divisor=depth_divisor,
        )
        repeats = round_repeats(
            repeats=block_args.pop("num_repeat"), depth_coefficient=depth_coefficient
        )
        
        for j in range(repeats):
            args = copy.deepcopy(block_args)
            if j > 0:
                args['strides'] = 1
                args['input_filters'] = args['output_filters']
            blocks_args_with_name.append([
                f"block{i + 1}{chr(j + 97)}_",
                args
            ])
            
    
    # build branched blocks
    for i, (name, args) in enumerate(blocks_args_with_name[:num_blocks_to_branch]):
        block = {0: MBConvBlock, 1: FusedMBConvBlock}[args.pop("conv_type")]
        
        total_input_filters = args['input_filters']
        total_output_filters = args['output_filters']
        l_input_filters = int(l_ratio * total_input_filters)
        l_output_filters = int(l_ratio * total_output_filters)
        ab_input_filters = total_input_filters - l_input_filters
        ab_output_filters = total_output_filters - l_output_filters
        
        args['input_filters'] = l_input_filters
        args['output_filters'] = l_output_filters
        x_l = block(
            activation=activation,
            bn_momentum=bn_momentum,
            survival_probability=drop_connect_rate * i / blocks,
            name=f'l_{name}',
            **args,
        )(x_l)
        
        args['input_filters'] = ab_input_filters
        args['output_filters'] = ab_output_filters
        x_ab = block(
            activation=activation,
            bn_momentum=bn_momentum,
            survival_probability=drop_connect_rate * i / blocks,
            name=f'ab_{name}',
            **args,
        )(x_ab)
        
    # concat
    if branch_stem:
        x = layers.Concatenate()([x_l, x_ab])
        
    # build remaining serial block
    for i, (name, args) in enumerate(blocks_args_with_name[num_blocks_to_branch:], start=num_blocks_to_branch):
        block = {0: MBConvBlock, 1: FusedMBConvBlock}[args.pop("conv_type")]
        
        x = block(
            activation=activation,
            bn_momentum=bn_momentum,
            survival_probability=drop_connect_rate * i / blocks,
            name=name,
            **args,
        )(x)
           
              
    # Build top
    top_filters = round_filters(
        filters=1280,
        width_coefficient=width_coefficient,
        min_depth=min_depth,
        depth_divisor=depth_divisor,
    )
    x = layers.Conv2D(
        filters=top_filters,
        kernel_size=1,
        strides=1,
        kernel_initializer=CONV_KERNEL_INITIALIZER,
        padding="same",
        data_format=backend.image_data_format(),
        use_bias=False,
        name="top_conv",
    )(x)
    x = layers.BatchNormalization(
        axis=bn_axis,
        momentum=bn_momentum,
        name="top_bn",
    )(x)
    x = layers.Activation(activation=activation, name="top_activation")(x)

    if include_top:
        x = layers.GlobalAveragePooling2D(name="avg_pool")(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate, name="top_dropout")(x)
        x = layers.Dense(
            classes,
            activation=classifier_activation,
            kernel_initializer=DENSE_KERNEL_INITIALIZER,
            bias_initializer=initializers.Constant(0.0),
            name="predictions",
        )(x)
    else:
        if pooling == "avg":
            x = layers.GlobalAveragePooling2D(name="avg_pool")(x)
        elif pooling == "max":
            x = layers.GlobalMaxPooling2D(name="max_pool")(x)

            
    # Create model.
    if branch_stem:
        model = Functional([l_inputs, ab_inputs], x, name=model_name)
    else:
        model = Functional(inputs, x, name=model_name)
        
    return model

# %%
def EfficientNetV2B0(
    include_top=True,
    l_input_shape=None,
    ab_input_shape=None,
    l_ratio=0.5,
    num_blocks_to_branch=3,
    width_coefficient=1.0,
    depth_coefficient=1.0,
    dropout_rate=0.5,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
    branch_stem=True,
    input_shape=None
):
    return EfficientNetV2(
        width_coefficient=width_coefficient,
        depth_coefficient=depth_coefficient,
        dropout_rate=dropout_rate,
        default_size=224,
        model_name="efficientnetv2-b0",
        include_top=include_top,
        l_input_shape=l_input_shape,
        ab_input_shape=ab_input_shape,
        l_ratio=l_ratio,
        num_blocks_to_branch=num_blocks_to_branch,
        pooling=pooling,
        classes=classes,
        classifier_activation=classifier_activation,
        branch_stem=branch_stem,
        input_shape=input_shape
    )


def EfficientNetV2B1(
    include_top=True,
    l_input_shape=None,
    ab_input_shape=None,
    l_ratio=0.5,
    num_blocks_to_branch=3,
    width_coefficient=1.0,
    depth_coefficient=1.1,
    dropout_rate=0.5,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
):
    return EfficientNetV2(
        width_coefficient=width_coefficient,
        depth_coefficient=depth_coefficient,
        dropout_rate=dropout_rate,
        default_size=240,
        model_name="efficientnetv2-b1",
        include_top=include_top,
        l_input_shape=l_input_shape,
        ab_input_shape=ab_input_shape,
        l_ratio=l_ratio,
        num_blocks_to_branch=num_blocks_to_branch,
        pooling=pooling,
        classes=classes,
        classifier_activation=classifier_activation,
    )


def EfficientNetV2B2(
    include_top=True,
    l_input_shape=None,
    ab_input_shape=None,
    l_ratio=0.5,
    num_blocks_to_branch=3,
    width_coefficient=1.1,
    depth_coefficient=1.5,
    dropout_rate=0.5,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
):
    return EfficientNetV2(
        width_coefficient=width_coefficient,
        depth_coefficient=depth_coefficient,
        dropout_rate=dropout_rate,
        default_size=260,
        model_name="efficientnetv2-b2",
        include_top=include_top,
        l_input_shape=l_input_shape,
        ab_input_shape=ab_input_shape,
        l_ratio=l_ratio,
        num_blocks_to_branch=num_blocks_to_branch,
        pooling=pooling,
        classes=classes,
        classifier_activation=classifier_activation,
    )


def EfficientNetV2B3(
    include_top=True,
    l_input_shape=None,
    ab_input_shape=None,
    l_ratio=0.5,
    num_blocks_to_branch=3,
    width_coefficient=1.2,
    depth_coefficient=1.4,
    dropout_rate=0.5,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
):
    return EfficientNetV2(
        width_coefficient=width_coefficient,
        depth_coefficient=depth_coefficient,
        dropout_rate=dropout_rate,
        default_size=300,
        model_name="efficientnetv2-b3",
        include_top=include_top,
        l_input_shape=l_input_shape,
        ab_input_shape=ab_input_shape,
        l_ratio=l_ratio,
        num_blocks_to_branch=num_blocks_to_branch,
        pooling=pooling,
        classes=classes,
        classifier_activation=classifier_activation,
    )


def EfficientNetV2S(
    include_top=True,
    l_input_shape=None,
    ab_input_shape=None,
    l_ratio=0.5,
    num_blocks_to_branch=3,
    width_coefficient=1.0,
    depth_coefficient=1.0,
    dropout_rate=0.5,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
):
    return EfficientNetV2(
        width_coefficient=width_coefficient,
        depth_coefficient=depth_coefficient,
        dropout_rate=dropout_rate,
        default_size=384,
        model_name="efficientnetv2-s",
        include_top=include_top,
        l_input_shape=l_input_shape,
        ab_input_shape=ab_input_shape,
        l_ratio=l_ratio,
        num_blocks_to_branch=num_blocks_to_branch,
        pooling=pooling,
        classes=classes,
        classifier_activation=classifier_activation,
    )


def EfficientNetV2M(
    include_top=True,
    l_input_shape=None,
    ab_input_shape=None,
    l_ratio=0.5,
    num_blocks_to_branch=3,
    width_coefficient=1.0,
    depth_coefficient=1.0,
    dropout_rate=0.5,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
    include_preprocessing=True,
):
    return EfficientNetV2(
        width_coefficient=width_coefficient,
        depth_coefficient=depth_coefficient,
        default_size=480,
        model_name="efficientnetv2-m",
        include_top=include_top,
        l_input_shape=l_input_shape,
        ab_input_shape=ab_input_shape,
        l_ratio=l_ratio,
        num_blocks_to_branch=num_blocks_to_branch,
        pooling=pooling,
        classes=classes,
        classifier_activation=classifier_activation,
    )


def EfficientNetV2L(
    include_top=True,
    l_input_shape=None,
    ab_input_shape=None,
    l_ratio=0.5,
    num_blocks_to_branch=3,
    width_coefficient=1.0,
    depth_coefficient=1.0,
    dropout_rate=0.5,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
    include_preprocessing=True,
):
    return EfficientNetV2(
        width_coefficient=width_coefficient,
        depth_coefficient=depth_coefficient,
        dropout_rate=dropout_rate,
        default_size=480,
        model_name="efficientnetv2-l",
        include_top=include_top,
        l_input_shape=l_input_shape,
        ab_input_shape=ab_input_shape,
        l_ratio=l_ratio,
        num_blocks_to_branch=num_blocks_to_branch,
        pooling=pooling,
        classes=classes,
        classifier_activation=classifier_activation,
    )

# %% [markdown]
# # ZERO BLOCK BRANCHED (ONLY STEM LAYER BRANCHED)

# %%
model = EfficientNetV2B0(
    l_input_shape=(128, 128, 1),
    ab_input_shape=(128, 128, 2),
    l_ratio=0.5,
    depth_coefficient=0.5,
    width_coefficient=0.5,
    num_blocks_to_branch=0,
    classes=38
)
model.compile(
        loss='categorical_crossentropy',
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
        metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "efficientnetv2-b0"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ l_stem_conv         │ (None, 64, 64, 8) │         72 │ input_layer[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ab_stem_conv        │ (None, 64, 64, 8) │        144 │ input_layer_1[0]… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ l_stem_bn           │ (None, 64, 64, 8) │         32 │ l_stem_conv[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ab_stem_bn          │ (None, 64, 64, 8) │         32 │ ab_stem_conv[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ l_stem_activation   │ (None, 64, 64, 8) │          0 │ l_stem_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ab_stem_activation  │ (None, 64, 64, 8) │          0 │ ab_stem_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 64,    │          0 │ l_stem_activatio… │
# │ (Concatenate)       │ 16)               │            │ ab_stem_activati… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 64, 64, 8) │      1,152 │ concatenate[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn  │ (None, 64, 64, 8) │         32 │ block1a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_ac… │ (None, 64, 64, 8) │          0 │ block1a_project_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 32, 32,    │      2,304 │ block1a_project_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 32, 32,    │        128 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 32, 32,    │          0 │ block2a_expand_b… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 32, 32,    │        512 │ block2a_expand_a… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 32, 32,    │         64 │ block2a_project_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 16, 16,    │      9,216 │ block2a_project_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 16, 16,    │        256 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 16, 16,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 16, 16,    │      1,536 │ block3a_expand_a… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 16, 16,    │         96 │ block3a_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_conv │ (None, 16, 16,    │      2,304 │ block3a_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_bn   │ (None, 16, 16,    │        384 │ block4a_expand_c… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_act… │ (None, 16, 16,    │          0 │ block4a_expand_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv2     │ (None, 8, 8, 96)  │        864 │ block4a_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_bn          │ (None, 8, 8, 96)  │        384 │ block4a_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_activation  │ (None, 8, 8, 96)  │          0 │ block4a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_squeeze  │ (None, 96)        │          0 │ block4a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reshape  │ (None, 1, 1, 96)  │          0 │ block4a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reduce   │ (None, 1, 1, 6)   │        582 │ block4a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_expand   │ (None, 1, 1, 96)  │        672 │ block4a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_excite   │ (None, 8, 8, 96)  │          0 │ block4a_activati… │
# │ (Multiply)          │                   │            │ block4a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_co… │ (None, 8, 8, 48)  │      4,608 │ block4a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_bn  │ (None, 8, 8, 48)  │        192 │ block4a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_conv │ (None, 8, 8, 192) │      9,216 │ block4a_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_bn   │ (None, 8, 8, 192) │        768 │ block4b_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_act… │ (None, 8, 8, 192) │          0 │ block4b_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_dwconv2     │ (None, 8, 8, 192) │      1,728 │ block4b_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_bn          │ (None, 8, 8, 192) │        768 │ block4b_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_activation  │ (None, 8, 8, 192) │          0 │ block4b_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_squeeze  │ (None, 192)       │          0 │ block4b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reshape  │ (None, 1, 1, 192) │          0 │ block4b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reduce   │ (None, 1, 1, 12)  │      2,316 │ block4b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_expand   │ (None, 1, 1, 192) │      2,496 │ block4b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_excite   │ (None, 8, 8, 192) │          0 │ block4b_activati… │
# │ (Multiply)          │                   │            │ block4b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_co… │ (None, 8, 8, 48)  │      9,216 │ block4b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_bn  │ (None, 8, 8, 48)  │        192 │ block4b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_drop        │ (None, 8, 8, 48)  │          0 │ block4b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_add (Add)   │ (None, 8, 8, 48)  │          0 │ block4b_drop[0][… │
# │                     │                   │            │ block4a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_conv │ (None, 8, 8, 288) │     13,824 │ block4b_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_bn   │ (None, 8, 8, 288) │      1,152 │ block5a_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_act… │ (None, 8, 8, 288) │          0 │ block5a_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_dwconv2     │ (None, 8, 8, 288) │      2,592 │ block5a_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_bn          │ (None, 8, 8, 288) │      1,152 │ block5a_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_activation  │ (None, 8, 8, 288) │          0 │ block5a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_squeeze  │ (None, 288)       │          0 │ block5a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reshape  │ (None, 1, 1, 288) │          0 │ block5a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reduce   │ (None, 1, 1, 12)  │      3,468 │ block5a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_expand   │ (None, 1, 1, 288) │      3,744 │ block5a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_excite   │ (None, 8, 8, 288) │          0 │ block5a_activati… │
# │ (Multiply)          │                   │            │ block5a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_co… │ (None, 8, 8, 56)  │     16,128 │ block5a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_bn  │ (None, 8, 8, 56)  │        224 │ block5a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_conv │ (None, 8, 8, 336) │     18,816 │ block5a_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_bn   │ (None, 8, 8, 336) │      1,344 │ block5b_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_act… │ (None, 8, 8, 336) │          0 │ block5b_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_dwconv2     │ (None, 8, 8, 336) │      3,024 │ block5b_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_bn          │ (None, 8, 8, 336) │      1,344 │ block5b_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_activation  │ (None, 8, 8, 336) │          0 │ block5b_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_squeeze  │ (None, 336)       │          0 │ block5b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reshape  │ (None, 1, 1, 336) │          0 │ block5b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reduce   │ (None, 1, 1, 14)  │      4,718 │ block5b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_expand   │ (None, 1, 1, 336) │      5,040 │ block5b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_excite   │ (None, 8, 8, 336) │          0 │ block5b_activati… │
# │ (Multiply)          │                   │            │ block5b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_co… │ (None, 8, 8, 56)  │     18,816 │ block5b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_bn  │ (None, 8, 8, 56)  │        224 │ block5b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_drop        │ (None, 8, 8, 56)  │          0 │ block5b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_add (Add)   │ (None, 8, 8, 56)  │          0 │ block5b_drop[0][… │
# │                     │                   │            │ block5a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_conv │ (None, 8, 8, 336) │     18,816 │ block5b_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_bn   │ (None, 8, 8, 336) │      1,344 │ block5c_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_act… │ (None, 8, 8, 336) │          0 │ block5c_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_dwconv2     │ (None, 8, 8, 336) │      3,024 │ block5c_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_bn          │ (None, 8, 8, 336) │      1,344 │ block5c_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_activation  │ (None, 8, 8, 336) │          0 │ block5c_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_squeeze  │ (None, 336)       │          0 │ block5c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reshape  │ (None, 1, 1, 336) │          0 │ block5c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reduce   │ (None, 1, 1, 14)  │      4,718 │ block5c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_expand   │ (None, 1, 1, 336) │      5,040 │ block5c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_excite   │ (None, 8, 8, 336) │          0 │ block5c_activati… │
# │ (Multiply)          │                   │            │ block5c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_co… │ (None, 8, 8, 56)  │     18,816 │ block5c_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_bn  │ (None, 8, 8, 56)  │        224 │ block5c_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_drop        │ (None, 8, 8, 56)  │          0 │ block5c_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_add (Add)   │ (None, 8, 8, 56)  │          0 │ block5c_drop[0][… │
# │                     │                   │            │ block5b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_conv │ (None, 8, 8, 336) │     18,816 │ block5c_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_bn   │ (None, 8, 8, 336) │      1,344 │ block6a_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_act… │ (None, 8, 8, 336) │          0 │ block6a_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv2     │ (None, 4, 4, 336) │      3,024 │ block6a_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_bn          │ (None, 4, 4, 336) │      1,344 │ block6a_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_activation  │ (None, 4, 4, 336) │          0 │ block6a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_squeeze  │ (None, 336)       │          0 │ block6a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reshape  │ (None, 1, 1, 336) │          0 │ block6a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reduce   │ (None, 1, 1, 14)  │      4,718 │ block6a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_expand   │ (None, 1, 1, 336) │      5,040 │ block6a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_excite   │ (None, 4, 4, 336) │          0 │ block6a_activati… │
# │ (Multiply)          │                   │            │ block6a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_co… │ (None, 4, 4, 96)  │     32,256 │ block6a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_bn  │ (None, 4, 4, 96)  │        384 │ block6a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_conv │ (None, 4, 4, 576) │     55,296 │ block6a_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_bn   │ (None, 4, 4, 576) │      2,304 │ block6b_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_act… │ (None, 4, 4, 576) │          0 │ block6b_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_dwconv2     │ (None, 4, 4, 576) │      5,184 │ block6b_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_bn          │ (None, 4, 4, 576) │      2,304 │ block6b_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_activation  │ (None, 4, 4, 576) │          0 │ block6b_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_squeeze  │ (None, 576)       │          0 │ block6b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reshape  │ (None, 1, 1, 576) │          0 │ block6b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reduce   │ (None, 1, 1, 24)  │     13,848 │ block6b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_expand   │ (None, 1, 1, 576) │     14,400 │ block6b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_excite   │ (None, 4, 4, 576) │          0 │ block6b_activati… │
# │ (Multiply)          │                   │            │ block6b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_co… │ (None, 4, 4, 96)  │     55,296 │ block6b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_bn  │ (None, 4, 4, 96)  │        384 │ block6b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_drop        │ (None, 4, 4, 96)  │          0 │ block6b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_add (Add)   │ (None, 4, 4, 96)  │          0 │ block6b_drop[0][… │
# │                     │                   │            │ block6a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_conv │ (None, 4, 4, 576) │     55,296 │ block6b_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_bn   │ (None, 4, 4, 576) │      2,304 │ block6c_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_act… │ (None, 4, 4, 576) │          0 │ block6c_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_dwconv2     │ (None, 4, 4, 576) │      5,184 │ block6c_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_bn          │ (None, 4, 4, 576) │      2,304 │ block6c_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_activation  │ (None, 4, 4, 576) │          0 │ block6c_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_squeeze  │ (None, 576)       │          0 │ block6c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reshape  │ (None, 1, 1, 576) │          0 │ block6c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reduce   │ (None, 1, 1, 24)  │     13,848 │ block6c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_expand   │ (None, 1, 1, 576) │     14,400 │ block6c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_excite   │ (None, 4, 4, 576) │          0 │ block6c_activati… │
# │ (Multiply)          │                   │            │ block6c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_co… │ (None, 4, 4, 96)  │     55,296 │ block6c_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_bn  │ (None, 4, 4, 96)  │        384 │ block6c_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_drop        │ (None, 4, 4, 96)  │          0 │ block6c_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_add (Add)   │ (None, 4, 4, 96)  │          0 │ block6c_drop[0][… │
# │                     │                   │            │ block6b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_conv │ (None, 4, 4, 576) │     55,296 │ block6c_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_bn   │ (None, 4, 4, 576) │      2,304 │ block6d_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_act… │ (None, 4, 4, 576) │          0 │ block6d_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_dwconv2     │ (None, 4, 4, 576) │      5,184 │ block6d_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_bn          │ (None, 4, 4, 576) │      2,304 │ block6d_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_activation  │ (None, 4, 4, 576) │          0 │ block6d_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_squeeze  │ (None, 576)       │          0 │ block6d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reshape  │ (None, 1, 1, 576) │          0 │ block6d_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reduce   │ (None, 1, 1, 24)  │     13,848 │ block6d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_expand   │ (None, 1, 1, 576) │     14,400 │ block6d_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_excite   │ (None, 4, 4, 576) │          0 │ block6d_activati… │
# │ (Multiply)          │                   │            │ block6d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_co… │ (None, 4, 4, 96)  │     55,296 │ block6d_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_bn  │ (None, 4, 4, 96)  │        384 │ block6d_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_drop        │ (None, 4, 4, 96)  │          0 │ block6d_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_add (Add)   │ (None, 4, 4, 96)  │          0 │ block6d_drop[0][… │
# │                     │                   │            │ block6c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 4, 4, 640) │     61,440 │ block6d_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 4, 4, 640) │      2,560 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 4, 4, 640) │          0 │ top_bn[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 640)       │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_dropout         │ (None, 640)       │          0 │ avg_pool[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ predictions (Dense) │ (None, 38)        │     24,358 │ top_dropout[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 803,534 (3.07 MB)
#  Trainable params: 787,390 (3.00 MB)
#  Non-trainable params: 16,144 (63.06 KB)

# %%
checkpoint_path = "/kaggle/working/two_branch_efficientnetv2scustom_0block_5050/cp-{epoch:04d}.keras"
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                         monitor='val_accuracy',
                                                         save_weights_only=False,
                                                         save_best_only=True,
                                                         mode='max',
                                                         verbose=1)

# %%
history = model.fit(
    batched_train,
    validation_data=batched_validation,
    verbose=1,
    epochs=25,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/25
#       1/Unknown 76s 76s/step - accuracy: 0.0312 - loss: 4.0913
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718986435.678303      86 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1718986435.746840      86 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#    1188/Unknown 652s 485ms/step - accuracy: 0.4152 - loss: 2.1849
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# W0000 00:00:1718987029.774060      85 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.63600, saving model to /kaggle/working/two_branch_efficientnetv2scustom_0block_5050/cp-0001.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 816s 623ms/step - accuracy: 0.4153 - loss: 2.1844 - val_accuracy: 0.6360 - val_loss: 1.2788
# Epoch 2/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7491 - loss: 0.8092
# Epoch 2: val_accuracy improved from 0.63600 to 0.78201, saving model to /kaggle/working/two_branch_efficientnetv2scustom_0block_5050/cp-0002.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.7491 - loss: 0.8090 - val_accuracy: 0.7820 - val_loss: 0.6842
# Epoch 3/25
# 1185/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8162 - loss: 0.5972
# Epoch 3: val_accuracy improved from 0.78201 to 0.84081, saving model to /kaggle/working/two_branch_efficientnetv2scustom_0block_5050/cp-0003.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.8162 - loss: 0.5971 - val_accuracy: 0.8408 - val_loss: 0.4918
# Epoch 4/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8402 - loss: 0.5043
# Epoch 4: val_accuracy did not improve from 0.84081
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.8402 - loss: 0.5042 - val_accuracy: 0.6767 - val_loss: 1.3138
# Epoch 5/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8637 - loss: 0.4355
# Epoch 5: val_accuracy did not improve from 0.84081
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.8637 - loss: 0.4355 - val_accuracy: 0.7519 - val_loss: 0.8864
# Epoch 6/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8806 - loss: 0.3792
# Epoch 6: val_accuracy improved from 0.84081 to 0.86331, saving model to /kaggle/working/two_branch_efficientnetv2scustom_0block_5050/cp-0006.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.8806 - loss: 0.3792 - val_accuracy: 0.8633 - val_loss: 0.4668
# Epoch 7/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8866 - loss: 0.3510
# Epoch 7: val_accuracy improved from 0.86331 to 0.88801, saving model to /kaggle/working/two_branch_efficientnetv2scustom_0block_5050/cp-0007.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.8866 - loss: 0.3510 - val_accuracy: 0.8880 - val_loss: 0.3812
# Epoch 8/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8968 - loss: 0.3336
# Epoch 8: val_accuracy improved from 0.88801 to 0.91723, saving model to /kaggle/working/two_branch_efficientnetv2scustom_0block_5050/cp-0008.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.8968 - loss: 0.3336 - val_accuracy: 0.9172 - val_loss: 0.2670
# Epoch 9/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9034 - loss: 0.3042
# Epoch 9: val_accuracy did not improve from 0.91723
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 20ms/step - accuracy: 0.9034 - loss: 0.3042 - val_accuracy: 0.9047 - val_loss: 0.3245
# Epoch 10/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9083 - loss: 0.2962
# Epoch 10: val_accuracy improved from 0.91723 to 0.92976, saving model to /kaggle/working/two_branch_efficientnetv2scustom_0block_5050/cp-0010.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.9083 - loss: 0.2962 - val_accuracy: 0.9298 - val_loss: 0.2291
# Epoch 11/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9162 - loss: 0.2663
# Epoch 11: val_accuracy did not improve from 0.92976
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.9162 - loss: 0.2663 - val_accuracy: 0.9252 - val_loss: 0.2480
# Epoch 12/25
# 1185/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9185 - loss: 0.2624
# Epoch 12: val_accuracy did not improve from 0.92976
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 20ms/step - accuracy: 0.9185 - loss: 0.2624 - val_accuracy: 0.9224 - val_loss: 0.2739
# Epoch 13/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9218 - loss: 0.2589
# Epoch 13: val_accuracy did not improve from 0.92976
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.9218 - loss: 0.2589 - val_accuracy: 0.9216 - val_loss: 0.2725
# Epoch 14/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9231 - loss: 0.2456
# Epoch 14: val_accuracy improved from 0.92976 to 0.93299, saving model to /kaggle/working/two_branch_efficientnetv2scustom_0block_5050/cp-0014.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 20ms/step - accuracy: 0.9231 - loss: 0.2456 - val_accuracy: 0.9330 - val_loss: 0.2275
# Epoch 15/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9329 - loss: 0.2222
# Epoch 15: val_accuracy improved from 0.93299 to 0.94101, saving model to /kaggle/working/two_branch_efficientnetv2scustom_0block_5050/cp-0015.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 20ms/step - accuracy: 0.9329 - loss: 0.2222 - val_accuracy: 0.9410 - val_loss: 0.2176
# Epoch 16/25
# 1185/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9263 - loss: 0.2476
# Epoch 16: val_accuracy did not improve from 0.94101
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.9263 - loss: 0.2476 - val_accuracy: 0.9298 - val_loss: 0.2503
# Epoch 17/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9338 - loss: 0.2236
# Epoch 17: val_accuracy did not improve from 0.94101
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 20ms/step - accuracy: 0.9338 - loss: 0.2236 - val_accuracy: 0.9359 - val_loss: 0.2341
# Epoch 18/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9389 - loss: 0.1972
# Epoch 18: val_accuracy improved from 0.94101 to 0.94543, saving model to /kaggle/working/two_branch_efficientnetv2scustom_0block_5050/cp-0018.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.9389 - loss: 0.1972 - val_accuracy: 0.9454 - val_loss: 0.1996
# Epoch 19/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9399 - loss: 0.2078
# Epoch 19: val_accuracy did not improve from 0.94543
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.9399 - loss: 0.2078 - val_accuracy: 0.9065 - val_loss: 0.3564
# Epoch 20/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9451 - loss: 0.1917
# Epoch 20: val_accuracy did not improve from 0.94543
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.9451 - loss: 0.1917 - val_accuracy: 0.9450 - val_loss: 0.2269
# Epoch 21/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9445 - loss: 0.1894
# Epoch 21: val_accuracy did not improve from 0.94543
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.9445 - loss: 0.1894 - val_accuracy: 0.9288 - val_loss: 0.2741
# Epoch 22/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9443 - loss: 0.1977
# Epoch 22: val_accuracy did not improve from 0.94543
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.9443 - loss: 0.1977 - val_accuracy: 0.9220 - val_loss: 0.3254
# Epoch 23/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9484 - loss: 0.1802
# Epoch 23: val_accuracy did not improve from 0.94543
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.9484 - loss: 0.1802 - val_accuracy: 0.9033 - val_loss: 0.4626
# Epoch 24/25
# 1185/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9468 - loss: 0.1837
# Epoch 24: val_accuracy did not improve from 0.94543
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.9468 - loss: 0.1837 - val_accuracy: 0.9443 - val_loss: 0.2271
# Epoch 25/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9525 - loss: 0.1722
# Epoch 25: val_accuracy did not improve from 0.94543
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 20ms/step - accuracy: 0.9525 - loss: 0.1722 - val_accuracy: 0.9440 - val_loss: 0.2292

# %%
# Plot the validation and training curves separately
def plot_loss_curves(history):
    """
    Returns separate loss curves for training and validation metrics
    """
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']

    epochs = range(len(history.history['loss'])) # How many epochs


    # Plot loss
    plt.plot(epochs, loss, label="training_loss")
    plt.plot(epochs, val_loss, label="val_loss")
    plt.title("loss")
    plt.xlabel("epochs")
    plt.legend()

    # Plot accuracy
    plt.figure()
    plt.plot(epochs, accuracy, label="training_accuracy")
    plt.plot(epochs, val_accuracy, label="val_accuracy")
    plt.title("accuracy")
    plt.xlabel("epochs")
    plt.legend()

# %%
plot_loss_curves(history)

# %%
saved = tf.keras.models.load_model('/kaggle/working/two_branch_efficientnetv2scustom_0block_5050/cp-0018.keras')
saved.evaluate(batched_test, verbose=2)
# Out:
# W0000 00:00:1718987820.951353      85 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 171/171 - 88s - 516ms/step - accuracy: 0.9450 - loss: 0.1996
# [0.1995537281036377, 0.9450448751449585]

# %% [markdown]
# # ONE BLOCK BRANCHED

# %%
model = EfficientNetV2B0(
    l_input_shape=(128, 128, 1),
    ab_input_shape=(128, 128, 2),
    l_ratio=0.2,
    depth_coefficient=0.5,
    width_coefficient=0.5,
    num_blocks_to_branch=1,
    classes=38
)
model.compile(
        loss='categorical_crossentropy',
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
        metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "efficientnetv2-b0"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ l_stem_conv         │ (None, 64, 64, 3) │         27 │ input_layer[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ab_stem_conv        │ (None, 64, 64,    │        234 │ input_layer_1[0]… │
# │ (Conv2D)            │ 13)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ l_stem_bn           │ (None, 64, 64, 3) │         12 │ l_stem_conv[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ab_stem_bn          │ (None, 64, 64,    │         52 │ ab_stem_conv[0][… │
# │ (BatchNormalizatio… │ 13)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ l_stem_activation   │ (None, 64, 64, 3) │          0 │ l_stem_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ab_stem_activation  │ (None, 64, 64,    │          0 │ ab_stem_bn[0][0]  │
# │ (Activation)        │ 13)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ l_block1a_project_… │ (None, 64, 64, 1) │         27 │ l_stem_activatio… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ab_block1a_project… │ (None, 64, 64, 7) │        819 │ ab_stem_activati… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ l_block1a_project_… │ (None, 64, 64, 1) │          4 │ l_block1a_projec… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ab_block1a_project… │ (None, 64, 64, 7) │         28 │ ab_block1a_proje… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ l_block1a_project_… │ (None, 64, 64, 1) │          0 │ l_block1a_projec… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ab_block1a_project… │ (None, 64, 64, 7) │          0 │ ab_block1a_proje… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 64, 8) │          0 │ l_block1a_projec… │
# │ (Concatenate)       │                   │            │ ab_block1a_proje… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 32, 32,    │      2,304 │ concatenate[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 32, 32,    │        128 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 32, 32,    │          0 │ block2a_expand_b… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 32, 32,    │        512 │ block2a_expand_a… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 32, 32,    │         64 │ block2a_project_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 16, 16,    │      9,216 │ block2a_project_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 16, 16,    │        256 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 16, 16,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 16, 16,    │      1,536 │ block3a_expand_a… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 16, 16,    │         96 │ block3a_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_conv │ (None, 16, 16,    │      2,304 │ block3a_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_bn   │ (None, 16, 16,    │        384 │ block4a_expand_c… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_act… │ (None, 16, 16,    │          0 │ block4a_expand_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv2     │ (None, 8, 8, 96)  │        864 │ block4a_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_bn          │ (None, 8, 8, 96)  │        384 │ block4a_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_activation  │ (None, 8, 8, 96)  │          0 │ block4a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_squeeze  │ (None, 96)        │          0 │ block4a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reshape  │ (None, 1, 1, 96)  │          0 │ block4a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reduce   │ (None, 1, 1, 6)   │        582 │ block4a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_expand   │ (None, 1, 1, 96)  │        672 │ block4a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_excite   │ (None, 8, 8, 96)  │          0 │ block4a_activati… │
# │ (Multiply)          │                   │            │ block4a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_co… │ (None, 8, 8, 48)  │      4,608 │ block4a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_bn  │ (None, 8, 8, 48)  │        192 │ block4a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_conv │ (None, 8, 8, 192) │      9,216 │ block4a_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_bn   │ (None, 8, 8, 192) │        768 │ block4b_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_act… │ (None, 8, 8, 192) │          0 │ block4b_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_dwconv2     │ (None, 8, 8, 192) │      1,728 │ block4b_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_bn          │ (None, 8, 8, 192) │        768 │ block4b_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_activation  │ (None, 8, 8, 192) │          0 │ block4b_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_squeeze  │ (None, 192)       │          0 │ block4b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reshape  │ (None, 1, 1, 192) │          0 │ block4b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reduce   │ (None, 1, 1, 12)  │      2,316 │ block4b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_expand   │ (None, 1, 1, 192) │      2,496 │ block4b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_excite   │ (None, 8, 8, 192) │          0 │ block4b_activati… │
# │ (Multiply)          │                   │            │ block4b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_co… │ (None, 8, 8, 48)  │      9,216 │ block4b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_bn  │ (None, 8, 8, 48)  │        192 │ block4b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_drop        │ (None, 8, 8, 48)  │          0 │ block4b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_add (Add)   │ (None, 8, 8, 48)  │          0 │ block4b_drop[0][… │
# │                     │                   │            │ block4a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_conv │ (None, 8, 8, 288) │     13,824 │ block4b_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_bn   │ (None, 8, 8, 288) │      1,152 │ block5a_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_act… │ (None, 8, 8, 288) │          0 │ block5a_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_dwconv2     │ (None, 8, 8, 288) │      2,592 │ block5a_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_bn          │ (None, 8, 8, 288) │      1,152 │ block5a_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_activation  │ (None, 8, 8, 288) │          0 │ block5a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_squeeze  │ (None, 288)       │          0 │ block5a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reshape  │ (None, 1, 1, 288) │          0 │ block5a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reduce   │ (None, 1, 1, 12)  │      3,468 │ block5a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_expand   │ (None, 1, 1, 288) │      3,744 │ block5a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_excite   │ (None, 8, 8, 288) │          0 │ block5a_activati… │
# │ (Multiply)          │                   │            │ block5a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_co… │ (None, 8, 8, 56)  │     16,128 │ block5a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_bn  │ (None, 8, 8, 56)  │        224 │ block5a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_conv │ (None, 8, 8, 336) │     18,816 │ block5a_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_bn   │ (None, 8, 8, 336) │      1,344 │ block5b_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_act… │ (None, 8, 8, 336) │          0 │ block5b_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_dwconv2     │ (None, 8, 8, 336) │      3,024 │ block5b_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_bn          │ (None, 8, 8, 336) │      1,344 │ block5b_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_activation  │ (None, 8, 8, 336) │          0 │ block5b_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_squeeze  │ (None, 336)       │          0 │ block5b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reshape  │ (None, 1, 1, 336) │          0 │ block5b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reduce   │ (None, 1, 1, 14)  │      4,718 │ block5b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_expand   │ (None, 1, 1, 336) │      5,040 │ block5b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_excite   │ (None, 8, 8, 336) │          0 │ block5b_activati… │
# │ (Multiply)          │                   │            │ block5b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_co… │ (None, 8, 8, 56)  │     18,816 │ block5b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_bn  │ (None, 8, 8, 56)  │        224 │ block5b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_drop        │ (None, 8, 8, 56)  │          0 │ block5b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_add (Add)   │ (None, 8, 8, 56)  │          0 │ block5b_drop[0][… │
# │                     │                   │            │ block5a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_conv │ (None, 8, 8, 336) │     18,816 │ block5b_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_bn   │ (None, 8, 8, 336) │      1,344 │ block5c_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_act… │ (None, 8, 8, 336) │          0 │ block5c_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_dwconv2     │ (None, 8, 8, 336) │      3,024 │ block5c_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_bn          │ (None, 8, 8, 336) │      1,344 │ block5c_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_activation  │ (None, 8, 8, 336) │          0 │ block5c_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_squeeze  │ (None, 336)       │          0 │ block5c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reshape  │ (None, 1, 1, 336) │          0 │ block5c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reduce   │ (None, 1, 1, 14)  │      4,718 │ block5c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_expand   │ (None, 1, 1, 336) │      5,040 │ block5c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_excite   │ (None, 8, 8, 336) │          0 │ block5c_activati… │
# │ (Multiply)          │                   │            │ block5c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_co… │ (None, 8, 8, 56)  │     18,816 │ block5c_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_bn  │ (None, 8, 8, 56)  │        224 │ block5c_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_drop        │ (None, 8, 8, 56)  │          0 │ block5c_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_add (Add)   │ (None, 8, 8, 56)  │          0 │ block5c_drop[0][… │
# │                     │                   │            │ block5b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_conv │ (None, 8, 8, 336) │     18,816 │ block5c_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_bn   │ (None, 8, 8, 336) │      1,344 │ block6a_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_act… │ (None, 8, 8, 336) │          0 │ block6a_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv2     │ (None, 4, 4, 336) │      3,024 │ block6a_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_bn          │ (None, 4, 4, 336) │      1,344 │ block6a_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_activation  │ (None, 4, 4, 336) │          0 │ block6a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_squeeze  │ (None, 336)       │          0 │ block6a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reshape  │ (None, 1, 1, 336) │          0 │ block6a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reduce   │ (None, 1, 1, 14)  │      4,718 │ block6a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_expand   │ (None, 1, 1, 336) │      5,040 │ block6a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_excite   │ (None, 4, 4, 336) │          0 │ block6a_activati… │
# │ (Multiply)          │                   │            │ block6a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_co… │ (None, 4, 4, 96)  │     32,256 │ block6a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_bn  │ (None, 4, 4, 96)  │        384 │ block6a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_conv │ (None, 4, 4, 576) │     55,296 │ block6a_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_bn   │ (None, 4, 4, 576) │      2,304 │ block6b_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_act… │ (None, 4, 4, 576) │          0 │ block6b_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_dwconv2     │ (None, 4, 4, 576) │      5,184 │ block6b_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_bn          │ (None, 4, 4, 576) │      2,304 │ block6b_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_activation  │ (None, 4, 4, 576) │          0 │ block6b_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_squeeze  │ (None, 576)       │          0 │ block6b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reshape  │ (None, 1, 1, 576) │          0 │ block6b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reduce   │ (None, 1, 1, 24)  │     13,848 │ block6b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_expand   │ (None, 1, 1, 576) │     14,400 │ block6b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_excite   │ (None, 4, 4, 576) │          0 │ block6b_activati… │
# │ (Multiply)          │                   │            │ block6b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_co… │ (None, 4, 4, 96)  │     55,296 │ block6b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_bn  │ (None, 4, 4, 96)  │        384 │ block6b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_drop        │ (None, 4, 4, 96)  │          0 │ block6b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_add (Add)   │ (None, 4, 4, 96)  │          0 │ block6b_drop[0][… │
# │                     │                   │            │ block6a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_conv │ (None, 4, 4, 576) │     55,296 │ block6b_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_bn   │ (None, 4, 4, 576) │      2,304 │ block6c_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_act… │ (None, 4, 4, 576) │          0 │ block6c_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_dwconv2     │ (None, 4, 4, 576) │      5,184 │ block6c_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_bn          │ (None, 4, 4, 576) │      2,304 │ block6c_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_activation  │ (None, 4, 4, 576) │          0 │ block6c_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_squeeze  │ (None, 576)       │          0 │ block6c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reshape  │ (None, 1, 1, 576) │          0 │ block6c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reduce   │ (None, 1, 1, 24)  │     13,848 │ block6c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_expand   │ (None, 1, 1, 576) │     14,400 │ block6c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_excite   │ (None, 4, 4, 576) │          0 │ block6c_activati… │
# │ (Multiply)          │                   │            │ block6c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_co… │ (None, 4, 4, 96)  │     55,296 │ block6c_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_bn  │ (None, 4, 4, 96)  │        384 │ block6c_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_drop        │ (None, 4, 4, 96)  │          0 │ block6c_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_add (Add)   │ (None, 4, 4, 96)  │          0 │ block6c_drop[0][… │
# │                     │                   │            │ block6b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_conv │ (None, 4, 4, 576) │     55,296 │ block6c_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_bn   │ (None, 4, 4, 576) │      2,304 │ block6d_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_act… │ (None, 4, 4, 576) │          0 │ block6d_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_dwconv2     │ (None, 4, 4, 576) │      5,184 │ block6d_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_bn          │ (None, 4, 4, 576) │      2,304 │ block6d_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_activation  │ (None, 4, 4, 576) │          0 │ block6d_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_squeeze  │ (None, 576)       │          0 │ block6d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reshape  │ (None, 1, 1, 576) │          0 │ block6d_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reduce   │ (None, 1, 1, 24)  │     13,848 │ block6d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_expand   │ (None, 1, 1, 576) │     14,400 │ block6d_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_excite   │ (None, 4, 4, 576) │          0 │ block6d_activati… │
# │ (Multiply)          │                   │            │ block6d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_co… │ (None, 4, 4, 96)  │     55,296 │ block6d_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_bn  │ (None, 4, 4, 96)  │        384 │ block6d_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_drop        │ (None, 4, 4, 96)  │          0 │ block6d_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_add (Add)   │ (None, 4, 4, 96)  │          0 │ block6d_drop[0][… │
# │                     │                   │            │ block6c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 4, 4, 640) │     61,440 │ block6d_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 4, 4, 640) │      2,560 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 4, 4, 640) │          0 │ top_bn[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 640)       │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_dropout         │ (None, 640)       │          0 │ avg_pool[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ predictions (Dense) │ (None, 38)        │     24,358 │ top_dropout[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 803,273 (3.06 MB)
#  Trainable params: 787,129 (3.00 MB)
#  Non-trainable params: 16,144 (63.06 KB)

# %%
checkpoint_path = "/kaggle/working/two_branch_efficientnetv2scustom_1block_2080/cp-{epoch:04d}.keras"
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                         monitor='val_accuracy',
                                                         save_weights_only=False,
                                                         save_best_only=True,
                                                         mode='max',
                                                         verbose=1)

# %%
history = model.fit(
    batched_train,
    validation_data=batched_validation,
    verbose=1,
    epochs=25,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/25
#       1/Unknown 78s 78s/step - accuracy: 0.0312 - loss: 4.1961
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718991371.373482      87 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1718991371.443037      87 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#    1188/Unknown 647s 480ms/step - accuracy: 0.3952 - loss: 2.2805
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# W0000 00:00:1718991959.611774      86 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.67250, saving model to /kaggle/working/two_branch_efficientnetv2scustom_1block_2080/cp-0001.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 809s 616ms/step - accuracy: 0.3953 - loss: 2.2800 - val_accuracy: 0.6725 - val_loss: 1.0960
# Epoch 2/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7347 - loss: 0.8665
# Epoch 2: val_accuracy improved from 0.67250 to 0.77104, saving model to /kaggle/working/two_branch_efficientnetv2scustom_1block_2080/cp-0002.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.7348 - loss: 0.8664 - val_accuracy: 0.7710 - val_loss: 0.7597
# Epoch 3/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8108 - loss: 0.6103
# Epoch 3: val_accuracy improved from 0.77104 to 0.85870, saving model to /kaggle/working/two_branch_efficientnetv2scustom_1block_2080/cp-0003.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.8108 - loss: 0.6103 - val_accuracy: 0.8587 - val_loss: 0.4474
# Epoch 4/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8387 - loss: 0.5176
# Epoch 4: val_accuracy improved from 0.85870 to 0.87778, saving model to /kaggle/working/two_branch_efficientnetv2scustom_1block_2080/cp-0004.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.8387 - loss: 0.5175 - val_accuracy: 0.8778 - val_loss: 0.3847
# Epoch 5/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8629 - loss: 0.4429
# Epoch 5: val_accuracy improved from 0.87778 to 0.89815, saving model to /kaggle/working/two_branch_efficientnetv2scustom_1block_2080/cp-0005.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.8629 - loss: 0.4429 - val_accuracy: 0.8981 - val_loss: 0.3220
# Epoch 6/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8726 - loss: 0.4149
# Epoch 6: val_accuracy did not improve from 0.89815
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.8726 - loss: 0.4149 - val_accuracy: 0.8767 - val_loss: 0.3922
# Epoch 7/25
# 1185/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8825 - loss: 0.3842
# Epoch 7: val_accuracy did not improve from 0.89815
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.8825 - loss: 0.3841 - val_accuracy: 0.8652 - val_loss: 0.4521
# Epoch 8/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8939 - loss: 0.3357
# Epoch 8: val_accuracy improved from 0.89815 to 0.91382, saving model to /kaggle/working/two_branch_efficientnetv2scustom_1block_2080/cp-0008.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.8939 - loss: 0.3357 - val_accuracy: 0.9138 - val_loss: 0.2881
# Epoch 9/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9024 - loss: 0.3158
# Epoch 9: val_accuracy improved from 0.91382 to 0.92405, saving model to /kaggle/working/two_branch_efficientnetv2scustom_1block_2080/cp-0009.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9024 - loss: 0.3158 - val_accuracy: 0.9240 - val_loss: 0.2373
# Epoch 10/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9056 - loss: 0.2977
# Epoch 10: val_accuracy did not improve from 0.92405
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.9056 - loss: 0.2977 - val_accuracy: 0.8921 - val_loss: 0.3793
# Epoch 11/25
# 1185/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9169 - loss: 0.2729
# Epoch 11: val_accuracy improved from 0.92405 to 0.93520, saving model to /kaggle/working/two_branch_efficientnetv2scustom_1block_2080/cp-0011.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 20ms/step - accuracy: 0.9169 - loss: 0.2728 - val_accuracy: 0.9352 - val_loss: 0.2130
# Epoch 12/25
# 1185/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9204 - loss: 0.2581
# Epoch 12: val_accuracy did not improve from 0.93520
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.9204 - loss: 0.2581 - val_accuracy: 0.9338 - val_loss: 0.2249
# Epoch 13/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9240 - loss: 0.2473
# Epoch 13: val_accuracy did not improve from 0.93520
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.9240 - loss: 0.2474 - val_accuracy: 0.9277 - val_loss: 0.2523
# Epoch 14/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9275 - loss: 0.2355
# Epoch 14: val_accuracy did not improve from 0.93520
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 24s 21ms/step - accuracy: 0.9275 - loss: 0.2355 - val_accuracy: 0.9333 - val_loss: 0.2248
# Epoch 15/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9313 - loss: 0.2254
# Epoch 15: val_accuracy did not improve from 0.93520
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9313 - loss: 0.2254 - val_accuracy: 0.9242 - val_loss: 0.2656
# Epoch 16/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9306 - loss: 0.2348
# Epoch 16: val_accuracy did not improve from 0.93520
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 22ms/step - accuracy: 0.9306 - loss: 0.2348 - val_accuracy: 0.8904 - val_loss: 0.4317
# Epoch 17/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9317 - loss: 0.2250
# Epoch 17: val_accuracy did not improve from 0.93520
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 41s 23ms/step - accuracy: 0.9317 - loss: 0.2250 - val_accuracy: 0.9299 - val_loss: 0.2482
# Epoch 18/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9366 - loss: 0.2158
# Epoch 18: val_accuracy did not improve from 0.93520
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9366 - loss: 0.2158 - val_accuracy: 0.9299 - val_loss: 0.2801
# Epoch 19/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9339 - loss: 0.2284
# Epoch 19: val_accuracy improved from 0.93520 to 0.93649, saving model to /kaggle/working/two_branch_efficientnetv2scustom_1block_2080/cp-0019.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9339 - loss: 0.2284 - val_accuracy: 0.9365 - val_loss: 0.2418
# Epoch 20/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9432 - loss: 0.1855
# Epoch 20: val_accuracy did not improve from 0.93649
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 22ms/step - accuracy: 0.9432 - loss: 0.1855 - val_accuracy: 0.9025 - val_loss: 0.3910
# Epoch 21/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9418 - loss: 0.1989
# Epoch 21: val_accuracy did not improve from 0.93649
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9418 - loss: 0.1989 - val_accuracy: 0.9328 - val_loss: 0.2806
# Epoch 22/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9447 - loss: 0.1986
# Epoch 22: val_accuracy improved from 0.93649 to 0.93806, saving model to /kaggle/working/two_branch_efficientnetv2scustom_1block_2080/cp-0022.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 22ms/step - accuracy: 0.9447 - loss: 0.1986 - val_accuracy: 0.9381 - val_loss: 0.2430
# Epoch 23/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9459 - loss: 0.1886
# Epoch 23: val_accuracy improved from 0.93806 to 0.94340, saving model to /kaggle/working/two_branch_efficientnetv2scustom_1block_2080/cp-0023.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 22ms/step - accuracy: 0.9459 - loss: 0.1886 - val_accuracy: 0.9434 - val_loss: 0.2216
# Epoch 24/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9519 - loss: 0.1697
# Epoch 24: val_accuracy improved from 0.94340 to 0.95152, saving model to /kaggle/working/two_branch_efficientnetv2scustom_1block_2080/cp-0024.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9519 - loss: 0.1697 - val_accuracy: 0.9515 - val_loss: 0.1842
# Epoch 25/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9460 - loss: 0.1953
# Epoch 25: val_accuracy did not improve from 0.95152
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 22ms/step - accuracy: 0.9460 - loss: 0.1953 - val_accuracy: 0.9479 - val_loss: 0.2213

# %%
plot_loss_curves(history)

# %%
saved = tf.keras.models.load_model('/kaggle/working/two_branch_efficientnetv2scustom_1block_2080/cp-0024.keras')
saved.evaluate(batched_test, verbose=2)
# Out:
# W0000 00:00:1718992853.107511      85 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 171/171 - 94s - 550ms/step - accuracy: 0.9564 - loss: 0.1609
# [0.16094310581684113, 0.9564022421836853]

# %% [markdown]
# # TWO BLOCK BRANCHED

# %%
model = EfficientNetV2B0(
    l_input_shape=(128, 128, 1),
    ab_input_shape=(128, 128, 2),
    l_ratio=0.2,
    depth_coefficient=0.5,
    width_coefficient=0.5,
    num_blocks_to_branch=2,
    classes=38
)
model.compile(
        loss='categorical_crossentropy',
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
        metrics=['accuracy']
)

# %%
checkpoint_path = "/kaggle/working/two_branch_efficientnetv2scustom_2block_2080/cp-{epoch:04d}.keras"
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                         monitor='val_accuracy',
                                                         save_weights_only=False,
                                                         save_best_only=True,
                                                         mode='max',
                                                         verbose=1)

# %%
history = model.fit(
    batched_train,
    validation_data=batched_validation,
    verbose=1,
    epochs=25,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/25
#       5/Unknown 59s 30ms/step - accuracy: 0.0602 - loss: 3.9556
# W0000 00:00:1718992996.987858      84 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#    1188/Unknown 115s 47ms/step - accuracy: 0.4329 - loss: 2.1222
# W0000 00:00:1718993056.926652      87 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.60651, saving model to /kaggle/working/two_branch_efficientnetv2scustom_2block_2080/cp-0001.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 125s 56ms/step - accuracy: 0.4331 - loss: 2.1217 - val_accuracy: 0.6065 - val_loss: 1.7976
# Epoch 2/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7580 - loss: 0.7862
# Epoch 2: val_accuracy improved from 0.60651 to 0.80551, saving model to /kaggle/working/two_branch_efficientnetv2scustom_2block_2080/cp-0002.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 24ms/step - accuracy: 0.7581 - loss: 0.7860 - val_accuracy: 0.8055 - val_loss: 0.6375
# Epoch 3/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8230 - loss: 0.5666
# Epoch 3: val_accuracy improved from 0.80551 to 0.83989, saving model to /kaggle/working/two_branch_efficientnetv2scustom_2block_2080/cp-0003.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 24ms/step - accuracy: 0.8230 - loss: 0.5665 - val_accuracy: 0.8399 - val_loss: 0.5337
# Epoch 4/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8459 - loss: 0.4919
# Epoch 4: val_accuracy improved from 0.83989 to 0.84994, saving model to /kaggle/working/two_branch_efficientnetv2scustom_2block_2080/cp-0004.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.8460 - loss: 0.4918 - val_accuracy: 0.8499 - val_loss: 0.4876
# Epoch 5/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8709 - loss: 0.4186
# Epoch 5: val_accuracy did not improve from 0.84994
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.8709 - loss: 0.4186 - val_accuracy: 0.8106 - val_loss: 0.7143
# Epoch 6/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8837 - loss: 0.3810
# Epoch 6: val_accuracy improved from 0.84994 to 0.85280, saving model to /kaggle/working/two_branch_efficientnetv2scustom_2block_2080/cp-0006.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.8838 - loss: 0.3809 - val_accuracy: 0.8528 - val_loss: 0.4973
# Epoch 7/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8959 - loss: 0.3284
# Epoch 7: val_accuracy improved from 0.85280 to 0.85907, saving model to /kaggle/working/two_branch_efficientnetv2scustom_2block_2080/cp-0007.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.8959 - loss: 0.3284 - val_accuracy: 0.8591 - val_loss: 0.4785
# Epoch 8/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8984 - loss: 0.3276
# Epoch 8: val_accuracy did not improve from 0.85907
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.8984 - loss: 0.3276 - val_accuracy: 0.8309 - val_loss: 0.7184
# Epoch 9/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9095 - loss: 0.2925
# Epoch 9: val_accuracy improved from 0.85907 to 0.87160, saving model to /kaggle/working/two_branch_efficientnetv2scustom_2block_2080/cp-0009.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9095 - loss: 0.2925 - val_accuracy: 0.8716 - val_loss: 0.4872
# Epoch 10/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9144 - loss: 0.2782
# Epoch 10: val_accuracy improved from 0.87160 to 0.94894, saving model to /kaggle/working/two_branch_efficientnetv2scustom_2block_2080/cp-0010.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9144 - loss: 0.2782 - val_accuracy: 0.9489 - val_loss: 0.1727
# Epoch 11/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9252 - loss: 0.2422
# Epoch 11: val_accuracy did not improve from 0.94894
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9252 - loss: 0.2422 - val_accuracy: 0.9483 - val_loss: 0.1650
# Epoch 12/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9298 - loss: 0.2320
# Epoch 12: val_accuracy did not improve from 0.94894
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 22ms/step - accuracy: 0.9298 - loss: 0.2320 - val_accuracy: 0.9256 - val_loss: 0.2883
# Epoch 13/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9324 - loss: 0.2252
# Epoch 13: val_accuracy did not improve from 0.94894
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9324 - loss: 0.2252 - val_accuracy: 0.8934 - val_loss: 0.4023
# Epoch 14/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9296 - loss: 0.2363
# Epoch 14: val_accuracy did not improve from 0.94894
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9296 - loss: 0.2363 - val_accuracy: 0.9319 - val_loss: 0.2380
# Epoch 15/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9338 - loss: 0.2206
# Epoch 15: val_accuracy did not improve from 0.94894
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9338 - loss: 0.2206 - val_accuracy: 0.9250 - val_loss: 0.2714
# Epoch 16/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9360 - loss: 0.2144
# Epoch 16: val_accuracy did not improve from 0.94894
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9360 - loss: 0.2144 - val_accuracy: 0.9454 - val_loss: 0.1952
# Epoch 17/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9429 - loss: 0.1959
# Epoch 17: val_accuracy did not improve from 0.94894
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 22ms/step - accuracy: 0.9430 - loss: 0.1959 - val_accuracy: 0.9453 - val_loss: 0.2141
# Epoch 18/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9398 - loss: 0.2066
# Epoch 18: val_accuracy did not improve from 0.94894
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9398 - loss: 0.2066 - val_accuracy: 0.9440 - val_loss: 0.2163
# Epoch 19/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9408 - loss: 0.2047
# Epoch 19: val_accuracy did not improve from 0.94894
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9408 - loss: 0.2046 - val_accuracy: 0.9469 - val_loss: 0.2071
# Epoch 20/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9476 - loss: 0.1803
# Epoch 20: val_accuracy improved from 0.94894 to 0.95225, saving model to /kaggle/working/two_branch_efficientnetv2scustom_2block_2080/cp-0020.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 22ms/step - accuracy: 0.9476 - loss: 0.1803 - val_accuracy: 0.9523 - val_loss: 0.1758
# Epoch 21/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9450 - loss: 0.1968
# Epoch 21: val_accuracy did not improve from 0.95225
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9450 - loss: 0.1968 - val_accuracy: 0.9272 - val_loss: 0.2920
# Epoch 22/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9487 - loss: 0.1767
# Epoch 22: val_accuracy did not improve from 0.95225
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9487 - loss: 0.1767 - val_accuracy: 0.9499 - val_loss: 0.2037
# Epoch 23/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9512 - loss: 0.1746
# Epoch 23: val_accuracy improved from 0.95225 to 0.95428, saving model to /kaggle/working/two_branch_efficientnetv2scustom_2block_2080/cp-0023.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9512 - loss: 0.1746 - val_accuracy: 0.9543 - val_loss: 0.1697
# Epoch 24/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9537 - loss: 0.1699
# Epoch 24: val_accuracy did not improve from 0.95428
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9537 - loss: 0.1699 - val_accuracy: 0.9380 - val_loss: 0.2670
# Epoch 25/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9560 - loss: 0.1605
# Epoch 25: val_accuracy improved from 0.95428 to 0.96092, saving model to /kaggle/working/two_branch_efficientnetv2scustom_2block_2080/cp-0025.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9560 - loss: 0.1605 - val_accuracy: 0.9609 - val_loss: 0.1608

# %%
plot_loss_curves(history)

# %%
saved = tf.keras.models.load_model('/kaggle/working/two_branch_efficientnetv2scustom_2block_2080/cp-0025.keras')
saved.evaluate(batched_test, verbose=2)
# Out:
# W0000 00:00:1718993749.636797      86 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 171/171 - 67s - 391ms/step - accuracy: 0.9617 - loss: 0.1551
# [0.15513204038143158, 0.9617146253585815]

# %% [markdown]
# # THREE BLOCK BRANCHED

# %%
model = EfficientNetV2B0(
    l_input_shape=(128, 128, 1),
    ab_input_shape=(128, 128, 2),
    l_ratio=0.2,
    depth_coefficient=0.5,
    width_coefficient=0.5,
    num_blocks_to_branch=3,
    classes=38
)
model.compile(
        loss='categorical_crossentropy',
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
        metrics=['accuracy']
)

# %%
checkpoint_path = "/kaggle/working/two_branch_efficientnetv2scustom_3block_2080/cp-{epoch:04d}.keras"
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                         monitor='val_accuracy',
                                                         save_weights_only=False,
                                                         save_best_only=True,
                                                         mode='max',
                                                         verbose=1)

# %%
history = model.fit(
    batched_train,
    validation_data=batched_validation,
    verbose=1,
    epochs=25,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/25
#       5/Unknown 64s 32ms/step - accuracy: 0.0690 - loss: 4.3351
# W0000 00:00:1718993878.117945      86 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#    1188/Unknown 124s 51ms/step - accuracy: 0.4246 - loss: 2.1523
# W0000 00:00:1718993942.963180      84 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.67158, saving model to /kaggle/working/two_branch_efficientnetv2scustom_3block_2080/cp-0001.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 135s 60ms/step - accuracy: 0.4248 - loss: 2.1517 - val_accuracy: 0.6716 - val_loss: 1.1030
# Epoch 2/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7652 - loss: 0.7542
# Epoch 2: val_accuracy did not improve from 0.67158
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 29s 24ms/step - accuracy: 0.7652 - loss: 0.7541 - val_accuracy: 0.4141 - val_loss: 3.0925
# Epoch 3/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8206 - loss: 0.5745
# Epoch 3: val_accuracy improved from 0.67158 to 0.85446, saving model to /kaggle/working/two_branch_efficientnetv2scustom_3block_2080/cp-0003.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 29s 24ms/step - accuracy: 0.8206 - loss: 0.5745 - val_accuracy: 0.8545 - val_loss: 0.4783
# Epoch 4/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8547 - loss: 0.4743
# Epoch 4: val_accuracy improved from 0.85446 to 0.88257, saving model to /kaggle/working/two_branch_efficientnetv2scustom_3block_2080/cp-0004.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 29s 24ms/step - accuracy: 0.8547 - loss: 0.4743 - val_accuracy: 0.8826 - val_loss: 0.3994
# Epoch 5/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8690 - loss: 0.4257
# Epoch 5: val_accuracy did not improve from 0.88257
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.8690 - loss: 0.4257 - val_accuracy: 0.8722 - val_loss: 0.4365
# Epoch 6/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8835 - loss: 0.3707
# Epoch 6: val_accuracy improved from 0.88257 to 0.90340, saving model to /kaggle/working/two_branch_efficientnetv2scustom_3block_2080/cp-0006.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 22ms/step - accuracy: 0.8835 - loss: 0.3707 - val_accuracy: 0.9034 - val_loss: 0.3273
# Epoch 7/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8930 - loss: 0.3411
# Epoch 7: val_accuracy did not improve from 0.90340
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 22ms/step - accuracy: 0.8930 - loss: 0.3411 - val_accuracy: 0.8561 - val_loss: 0.5152
# Epoch 8/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8997 - loss: 0.3171
# Epoch 8: val_accuracy improved from 0.90340 to 0.93041, saving model to /kaggle/working/two_branch_efficientnetv2scustom_3block_2080/cp-0008.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 24ms/step - accuracy: 0.8997 - loss: 0.3171 - val_accuracy: 0.9304 - val_loss: 0.2254
# Epoch 9/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9067 - loss: 0.2997
# Epoch 9: val_accuracy did not improve from 0.93041
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 24ms/step - accuracy: 0.9067 - loss: 0.2996 - val_accuracy: 0.8969 - val_loss: 0.3536
# Epoch 10/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9167 - loss: 0.2679
# Epoch 10: val_accuracy improved from 0.93041 to 0.94221, saving model to /kaggle/working/two_branch_efficientnetv2scustom_3block_2080/cp-0010.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 24ms/step - accuracy: 0.9167 - loss: 0.2679 - val_accuracy: 0.9422 - val_loss: 0.1971
# Epoch 11/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9221 - loss: 0.2564
# Epoch 11: val_accuracy did not improve from 0.94221
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9221 - loss: 0.2564 - val_accuracy: 0.9146 - val_loss: 0.2957
# Epoch 12/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9262 - loss: 0.2376
# Epoch 12: val_accuracy did not improve from 0.94221
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9262 - loss: 0.2376 - val_accuracy: 0.8852 - val_loss: 0.4792
# Epoch 13/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9257 - loss: 0.2424
# Epoch 13: val_accuracy improved from 0.94221 to 0.94331, saving model to /kaggle/working/two_branch_efficientnetv2scustom_3block_2080/cp-0013.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9257 - loss: 0.2424 - val_accuracy: 0.9433 - val_loss: 0.1993
# Epoch 14/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9339 - loss: 0.2207
# Epoch 14: val_accuracy improved from 0.94331 to 0.94820, saving model to /kaggle/working/two_branch_efficientnetv2scustom_3block_2080/cp-0014.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 29s 24ms/step - accuracy: 0.9339 - loss: 0.2207 - val_accuracy: 0.9482 - val_loss: 0.1922
# Epoch 15/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9377 - loss: 0.2110
# Epoch 15: val_accuracy did not improve from 0.94820
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9377 - loss: 0.2110 - val_accuracy: 0.9218 - val_loss: 0.2911
# Epoch 16/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9416 - loss: 0.1943
# Epoch 16: val_accuracy did not improve from 0.94820
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9416 - loss: 0.1943 - val_accuracy: 0.9335 - val_loss: 0.2651
# Epoch 17/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9431 - loss: 0.1997
# Epoch 17: val_accuracy improved from 0.94820 to 0.95299, saving model to /kaggle/working/two_branch_efficientnetv2scustom_3block_2080/cp-0017.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9431 - loss: 0.1997 - val_accuracy: 0.9530 - val_loss: 0.1750
# Epoch 18/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9465 - loss: 0.1789
# Epoch 18: val_accuracy improved from 0.95299 to 0.95548, saving model to /kaggle/working/two_branch_efficientnetv2scustom_3block_2080/cp-0018.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9465 - loss: 0.1790 - val_accuracy: 0.9555 - val_loss: 0.1633
# Epoch 19/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9462 - loss: 0.1791
# Epoch 19: val_accuracy improved from 0.95548 to 0.95603, saving model to /kaggle/working/two_branch_efficientnetv2scustom_3block_2080/cp-0019.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9462 - loss: 0.1791 - val_accuracy: 0.9560 - val_loss: 0.1776
# Epoch 20/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9488 - loss: 0.1733
# Epoch 20: val_accuracy did not improve from 0.95603
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9488 - loss: 0.1733 - val_accuracy: 0.9307 - val_loss: 0.2683
# Epoch 21/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9482 - loss: 0.1801
# Epoch 21: val_accuracy improved from 0.95603 to 0.95824, saving model to /kaggle/working/two_branch_efficientnetv2scustom_3block_2080/cp-0021.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9482 - loss: 0.1801 - val_accuracy: 0.9582 - val_loss: 0.1669
# Epoch 22/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9503 - loss: 0.1716
# Epoch 22: val_accuracy did not improve from 0.95824
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9503 - loss: 0.1716 - val_accuracy: 0.9532 - val_loss: 0.1931
# Epoch 23/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9547 - loss: 0.1607
# Epoch 23: val_accuracy did not improve from 0.95824
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 41s 23ms/step - accuracy: 0.9547 - loss: 0.1607 - val_accuracy: 0.9353 - val_loss: 0.2775
# Epoch 24/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9486 - loss: 0.1972
# Epoch 24: val_accuracy improved from 0.95824 to 0.95926, saving model to /kaggle/working/two_branch_efficientnetv2scustom_3block_2080/cp-0024.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 24ms/step - accuracy: 0.9486 - loss: 0.1972 - val_accuracy: 0.9593 - val_loss: 0.1689
# Epoch 25/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9575 - loss: 0.1568
# Epoch 25: val_accuracy did not improve from 0.95926
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9575 - loss: 0.1568 - val_accuracy: 0.9466 - val_loss: 0.2250

# %%
plot_loss_curves(history)

# %%
saved = tf.keras.models.load_model('/kaggle/working/two_branch_efficientnetv2scustom_3block_2080/cp-0024.keras')
saved.evaluate(batched_test, verbose=2)
# Out:
# W0000 00:00:1718994668.824351      85 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 171/171 - 63s - 371ms/step - accuracy: 0.9661 - loss: 0.1333
# [0.13329753279685974, 0.9661110043525696]

# %% [markdown]
# # FOUR BLOCK BRANCHED

# %%
model = EfficientNetV2B0(
    l_input_shape=(128, 128, 1),
    ab_input_shape=(128, 128, 2),
    l_ratio=0.2,
    depth_coefficient=0.5,
    width_coefficient=0.5,
    num_blocks_to_branch=4,
    classes=38
)
model.compile(
        loss='categorical_crossentropy',
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
        metrics=['accuracy']
)

# %%
checkpoint_path = "/kaggle/working/two_branch_efficientnetv2scustom_4block_2080/cp-{epoch:04d}.keras"
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                         monitor='val_accuracy',
                                                         save_weights_only=False,
                                                         save_best_only=True,
                                                         mode='max',
                                                         verbose=1)

# %%
history = model.fit(
    batched_train,
    validation_data=batched_validation,
    verbose=1,
    epochs=25,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/25
#       5/Unknown 69s 32ms/step - accuracy: 0.0356 - loss: 4.5048
# W0000 00:00:1718994814.561796      86 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#    1188/Unknown 134s 55ms/step - accuracy: 0.4622 - loss: 2.0282
# W0000 00:00:1718994884.320395      86 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.71730, saving model to /kaggle/working/two_branch_efficientnetv2scustom_4block_2080/cp-0001.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 146s 65ms/step - accuracy: 0.4624 - loss: 2.0276 - val_accuracy: 0.7173 - val_loss: 0.9722
# Epoch 2/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7902 - loss: 0.6759
# Epoch 2: val_accuracy improved from 0.71730 to 0.74753, saving model to /kaggle/working/two_branch_efficientnetv2scustom_4block_2080/cp-0002.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 30s 25ms/step - accuracy: 0.7902 - loss: 0.6757 - val_accuracy: 0.7475 - val_loss: 0.9551
# Epoch 3/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8487 - loss: 0.4836
# Epoch 3: val_accuracy improved from 0.74753 to 0.76256, saving model to /kaggle/working/two_branch_efficientnetv2scustom_4block_2080/cp-0003.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 30s 25ms/step - accuracy: 0.8487 - loss: 0.4836 - val_accuracy: 0.7626 - val_loss: 0.8501
# Epoch 4/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8702 - loss: 0.4130
# Epoch 4: val_accuracy improved from 0.76256 to 0.88838, saving model to /kaggle/working/two_branch_efficientnetv2scustom_4block_2080/cp-0004.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.8702 - loss: 0.4130 - val_accuracy: 0.8884 - val_loss: 0.3647
# Epoch 5/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8865 - loss: 0.3601
# Epoch 5: val_accuracy did not improve from 0.88838
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.8865 - loss: 0.3601 - val_accuracy: 0.8479 - val_loss: 0.4755
# Epoch 6/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8973 - loss: 0.3274
# Epoch 6: val_accuracy improved from 0.88838 to 0.91050, saving model to /kaggle/working/two_branch_efficientnetv2scustom_4block_2080/cp-0006.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 29s 24ms/step - accuracy: 0.8973 - loss: 0.3274 - val_accuracy: 0.9105 - val_loss: 0.2994
# Epoch 7/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9059 - loss: 0.2993
# Epoch 7: val_accuracy did not improve from 0.91050
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 24ms/step - accuracy: 0.9059 - loss: 0.2992 - val_accuracy: 0.8752 - val_loss: 0.4630
# Epoch 8/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9146 - loss: 0.2731
# Epoch 8: val_accuracy did not improve from 0.91050
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 29s 24ms/step - accuracy: 0.9146 - loss: 0.2731 - val_accuracy: 0.9066 - val_loss: 0.3080
# Epoch 9/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9241 - loss: 0.2430
# Epoch 9: val_accuracy improved from 0.91050 to 0.92211, saving model to /kaggle/working/two_branch_efficientnetv2scustom_4block_2080/cp-0009.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 29s 25ms/step - accuracy: 0.9241 - loss: 0.2430 - val_accuracy: 0.9221 - val_loss: 0.2676
# Epoch 10/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9255 - loss: 0.2417
# Epoch 10: val_accuracy did not improve from 0.92211
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 29s 24ms/step - accuracy: 0.9255 - loss: 0.2417 - val_accuracy: 0.8259 - val_loss: 0.7279
# Epoch 11/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9332 - loss: 0.2184
# Epoch 11: val_accuracy improved from 0.92211 to 0.95142, saving model to /kaggle/working/two_branch_efficientnetv2scustom_4block_2080/cp-0011.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 30s 25ms/step - accuracy: 0.9332 - loss: 0.2184 - val_accuracy: 0.9514 - val_loss: 0.1684
# Epoch 12/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9365 - loss: 0.2097
# Epoch 12: val_accuracy did not improve from 0.95142
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 29s 25ms/step - accuracy: 0.9365 - loss: 0.2097 - val_accuracy: 0.9082 - val_loss: 0.3648
# Epoch 13/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9317 - loss: 0.2261
# Epoch 13: val_accuracy did not improve from 0.95142
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 29s 24ms/step - accuracy: 0.9317 - loss: 0.2261 - val_accuracy: 0.9240 - val_loss: 0.2633
# Epoch 14/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9460 - loss: 0.1851
# Epoch 14: val_accuracy did not improve from 0.95142
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 24ms/step - accuracy: 0.9460 - loss: 0.1851 - val_accuracy: 0.9247 - val_loss: 0.2791
# Epoch 15/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9436 - loss: 0.1911
# Epoch 15: val_accuracy did not improve from 0.95142
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9436 - loss: 0.1911 - val_accuracy: 0.9275 - val_loss: 0.2794
# Epoch 16/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9465 - loss: 0.1759
# Epoch 16: val_accuracy did not improve from 0.95142
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9465 - loss: 0.1759 - val_accuracy: 0.9413 - val_loss: 0.2257
# Epoch 17/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9470 - loss: 0.1773
# Epoch 17: val_accuracy did not improve from 0.95142
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9470 - loss: 0.1773 - val_accuracy: 0.9333 - val_loss: 0.2644
# Epoch 18/25
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9482 - loss: 0.1810
# Epoch 18: val_accuracy improved from 0.95142 to 0.96156, saving model to /kaggle/working/two_branch_efficientnetv2scustom_4block_2080/cp-0018.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 24ms/step - accuracy: 0.9482 - loss: 0.1810 - val_accuracy: 0.9616 - val_loss: 0.1590
# Epoch 19/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9517 - loss: 0.1668
# Epoch 19: val_accuracy did not improve from 0.96156
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9517 - loss: 0.1668 - val_accuracy: 0.9452 - val_loss: 0.2245
# Epoch 20/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9531 - loss: 0.1626
# Epoch 20: val_accuracy did not improve from 0.96156
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.9531 - loss: 0.1626 - val_accuracy: 0.9480 - val_loss: 0.2073
# Epoch 21/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9564 - loss: 0.1556
# Epoch 21: val_accuracy did not improve from 0.96156
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9564 - loss: 0.1556 - val_accuracy: 0.9193 - val_loss: 0.3842
# Epoch 22/25
# 1187/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9577 - loss: 0.1534
# Epoch 22: val_accuracy improved from 0.96156 to 0.96359, saving model to /kaggle/working/two_branch_efficientnetv2scustom_4block_2080/cp-0022.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 24ms/step - accuracy: 0.9577 - loss: 0.1534 - val_accuracy: 0.9636 - val_loss: 0.1602
# Epoch 23/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9601 - loss: 0.1501
# Epoch 23: val_accuracy did not improve from 0.96359
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 29s 25ms/step - accuracy: 0.9601 - loss: 0.1501 - val_accuracy: 0.9507 - val_loss: 0.2028
# Epoch 24/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9617 - loss: 0.1401
# Epoch 24: val_accuracy did not improve from 0.96359
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 30s 25ms/step - accuracy: 0.9617 - loss: 0.1402 - val_accuracy: 0.9546 - val_loss: 0.2084
# Epoch 25/25
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9642 - loss: 0.1396
# Epoch 25: val_accuracy improved from 0.96359 to 0.97226, saving model to /kaggle/working/two_branch_efficientnetv2scustom_4block_2080/cp-0025.keras
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 29s 24ms/step - accuracy: 0.9642 - loss: 0.1396 - val_accuracy: 0.9723 - val_loss: 0.1294

# %%
plot_loss_curves(history)

# %%
saved = tf.keras.models.load_model('/kaggle/working/two_branch_efficientnetv2scustom_4block_2080/cp-0025.keras')
saved.evaluate(batched_test, verbose=2)
# Out:
# W0000 00:00:1718995630.368389      86 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 171/171 - 67s - 391ms/step - accuracy: 0.9736 - loss: 0.1159
# [0.1159353256225586, 0.9736215472221375]
